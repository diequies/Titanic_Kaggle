# %% [markdown]
# # Titanic Survival Kaggle Dataset

# %% [markdown]
# ## 1. Data Reading

# %% [markdown]
# Import necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as mpatches

# %% [markdown]
# To load both datasets, train and test. Also I will join them to be able to study and work with missing values better.

# %%
df_train = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
idx_train = df_train['PassengerId']
idx_test = df_test['PassengerId']
df_all = pd.concat([df_train, df_test],
                  axis = 0, sort = False)
df_all.set_index('PassengerId',
                drop = True,
                inplace = True)
df_all.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# 6                 0.0       3
# 7                 0.0       1
# 8                 0.0       3
# 9                 1.0       3
# 10                1.0       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S
# 10               1      0            237736  30.0708   NaN        C

# %%
df_all.tail(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1300              NaN       3
# 1301              NaN       3
# 1302              NaN       3
# 1303              NaN       1
# 1304              NaN       3
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                         Name     Sex   Age  \
# PassengerId
# 1300                         Riordan, Miss. Johanna Hannah""  female   NaN
# 1301                               Peacock, Miss. Treasteall  female   3.0
# 1302                                  Naughton, Miss. Hannah  female   NaN
# 1303         Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0
# 1304                          Henriksson, Miss. Jenny Lovisa  female  28.0
# 1305                                      Spector, Mr. Woolf    male   NaN
# 1306                            Oliva y Ocana, Dona. Fermina  female  39.0
# 1307                            Saether, Mr. Simon Sivertsen    male  38.5
# 1308                                     Ware, Mr. Frederick    male   NaN
# 1309                                Peter, Master. Michael J    male   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 1300             0      0              334915    7.7208   NaN        Q
# 1301             1      1  SOTON/O.Q. 3101315   13.7750   NaN        S
# 1302             0      0              365237    7.7500   NaN        Q
# 1303             1      0               19928   90.0000   C78        Q
# 1304             0      0              347086    7.7750   NaN        S
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C

# %% [markdown]
# We check now each column data type and the amount of NaN values.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Name      1309 non-null   object
#  3   Sex       1309 non-null   object
#  4   Age       1046 non-null   float64
#  5   SibSp     1309 non-null   int64
#  6   Parch     1309 non-null   int64
#  7   Ticket    1309 non-null   object
#  8   Fare      1308 non-null   float64
#  9   Cabin     295 non-null    object
#  10  Embarked  1307 non-null   object
# dtypes: float64(3), int64(3), object(5)
# memory usage: 122.7+ KB

# %% [markdown]
# We can see that the next variables have NaN that we will need to solve:
# - Age = 263 NaN values.
# - Fare = 1 NaN value.
# - Cabin = 1014 NaN values.
# - Embarked = 2 NaN values.

# %% [markdown]
# Now we should identify and describe each feature:
#
# - Categorical features:
#     - Pclass: Ordinal feature that shows the class of the ticket. 1: 1st Class, 2: 2nd Class, 3: 3rd Class
#     - Sex: Categorical feature that identifies the genre.
#     - Embarked: Categorical feature that identifies the port in which the passenger embarked.
#     - Survived: Categorical feature that shows whether the passenger survived or not.
#
# - Numerical features:
#     - Age: Continuous numerical feature of the age of the passenger.
#     - Fare: Continuous numerical feature of the cost of the ticket.
#     - SibSp: Discrete numerical feature showing the amount of siblings and spouse in the boat.
#     - Parch: Discrete numerical feature showing the amount of parents and children in the boat.
#
# - Other features:
#     - Name: Name of the passenger, we will use this feature to derive others more useful.
#     - Ticket: Ticket number of the passenger, we might use this feature to derive passengers that bought the ticket together.

# %%
df_all.describe(include = 'all')
# Out:
#           Survived       Pclass              Name   Sex          Age  \
# count   891.000000  1309.000000              1309  1309  1046.000000
# unique         NaN          NaN              1307     2          NaN
# top            NaN          NaN  Kelly, Mr. James  male          NaN
# freq           NaN          NaN                 2   843          NaN
# mean      0.383838     2.294882               NaN   NaN    29.881138
# std       0.486592     0.837836               NaN   NaN    14.413493
# min       0.000000     1.000000               NaN   NaN     0.170000
# 25%       0.000000     2.000000               NaN   NaN    21.000000
# 50%       0.000000     3.000000               NaN   NaN    28.000000
# 75%       1.000000     3.000000               NaN   NaN    39.000000
# max       1.000000     3.000000               NaN   NaN    80.000000
#
#               SibSp        Parch    Ticket         Fare        Cabin Embarked
# count   1309.000000  1309.000000      1309  1308.000000          295     1307
# unique          NaN          NaN       929          NaN          186        3
# top             NaN          NaN  CA. 2343          NaN  C23 C25 C27        S
# freq            NaN          NaN        11          NaN            6      914
# mean       0.498854     0.385027       NaN    33.295479          NaN      NaN
# std        1.041658     0.865560       NaN    51.758668          NaN      NaN
# min        0.000000     0.000000       NaN     0.000000          NaN      NaN
# 25%        0.000000     0.000000       NaN     7.895800          NaN      NaN
# 50%        0.000000     0.000000       NaN    14.454200          NaN      NaN
# 75%        1.000000     0.000000       NaN    31.275000          NaN      NaN
# max        8.000000     9.000000       NaN   512.329200          NaN      NaN

# %% [markdown]
# With just the initial information we can extract some insights:
#
# - The target feature is not completely balance, there are more people that died than that survived (38.3% - 61.7%)
# - More than half of the people were traveling in 3rd class and less than 25% were 1st class.
# - There were more male passengers that females (64.4% - 35.6%)
# - Most of the ticket fares were between 7 and 31 but there were some free ones and some very expensive.
# - Most of the people embarked at S.

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# ### 2.1. Columns Preparation

# %% [markdown]
# #### 2.1.1. Sex

# %% [markdown]
# We map the sex column to be numerical, so we can use it for NaN filling. Male: 0, Female: 1.

# %%
sex_dict = {'male': 0, 'female': 1}
df_all['Sex'] = df_all['Sex'].map(sex_dict)

# %% [markdown]
# #### 2.1.2. Embarked
#
# We can perform the same action to embarked.

# %%
embarked_dict = {'S': 0, 'C': 1, 'Q': 2}
df_all['Embarked'] = df_all['Embarked'].map(embarked_dict)

# %%
df_all
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# ...                                                        ...  ...   ...
# 1305                                        Spector, Mr. Woolf    0   NaN
# 1306                              Oliva y Ocana, Dona. Fermina    1  39.0
# 1307                              Saether, Mr. Simon Sivertsen    0  38.5
# 1308                                       Ware, Mr. Frederick    0   NaN
# 1309                                  Peter, Master. Michael J    0   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin  Embarked
# PassengerId
# 1                1      0           A/5 21171    7.2500   NaN       0.0
# 2                1      0            PC 17599   71.2833   C85       1.0
# 3                0      0    STON/O2. 3101282    7.9250   NaN       0.0
# 4                1      0              113803   53.1000  C123       0.0
# 5                0      0              373450    8.0500   NaN       0.0
# ...            ...    ...                 ...       ...   ...       ...
# 1305             0      0           A.5. 3236    8.0500   NaN       0.0
# 1306             0      0            PC 17758  108.9000  C105       1.0
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN       0.0
# 1308             0      0              359309    8.0500   NaN       0.0
# 1309             1      1                2668   22.3583   NaN       1.0
#
# [1309 rows x 11 columns]

# %% [markdown]
# #### 2.1.3. Fare
#
# We can also take advantage of Fare if we bine the feature converting it to discrete instead of continuous. But first we have to solve the missing value, and as it is just one, we can use the median aggregated by Pclass to fill it.

# %%
df_all['Fare'].fillna(df_all.groupby('Pclass')['Fare'].transform('median'),
                     inplace = True)
df_all['Fare_bin'] = pd.cut(df_all['Fare'],
                       5,
                       labels = [0,1,2,3,4])

# %%
df_all['Fare_bin'] = df_all['Fare_bin'].astype('int64')

# %% [markdown]
# #### 2.1.4. Age
#
# To substitute Age NaNs we can find some correlation with other features and then use the aggregated medians to fill them.

# %%
df_age_corr = df_all.drop(['Name', 'Ticket','Cabin'],
                         axis = 1)

# %%
df_age_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    1309 non-null   int64
#  2   Sex       1309 non-null   int64
#  3   Age       1046 non-null   float64
#  4   SibSp     1309 non-null   int64
#  5   Parch     1309 non-null   int64
#  6   Fare      1309 non-null   float64
#  7   Embarked  1307 non-null   float64
#  8   Fare_bin  1309 non-null   int64
# dtypes: float64(4), int64(5)
# memory usage: 102.3 KB

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.heatmap(df_age_corr.corr(),
           vmin = -1,
           vmax = 1,
           annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The highest correlation with age are Pclass, SibSp, Parch and Fare, so we can use them to aggregate the ages and take the means to substitute the NaN values.

# %%
pd.set_option('display.max_rows', 500)
df_age_corr.groupby(['Pclass','SibSp','Parch','Fare_bin'])['Age'].median()
# Out:
# Pclass  SibSp  Parch  Fare_bin
# 1       0      0      0           41.50
#                       1           35.00
#                       2           36.00
#                       4           35.00
#                1      0           30.00
#                       1           48.00
#                       2           33.50
#                       4           47.00
#                2      0           20.50
#                       1           24.00
#                       2           27.00
#         1      0      0           38.00
#                       1           27.00
#                       2           55.00
#                1      0           52.00
#                       1           45.00
#                       2           50.00
#                2      0           27.00
#                       1           19.50
#                3      2           54.50
#                4      2           62.00
#         2      0      0           54.00
#                       1           50.00
#                2      2           18.00
#         3      2      2           23.50
# 2       0      0      0           30.00
#                1      0           26.50
#                2      0           18.00
#                3      0           36.00
#         1      0      0           29.50
#                1      0           24.00
#                2      0           24.00
#                3      0           54.00
#         2      0      0           24.00
#                1      0           16.00
#                3      0           24.00
#         3      0      0           30.00
# 3       0      0      0           25.00
#                1      0           17.00
#                2      0           26.00
#                3      0           24.00
#                4      0           29.00
#                5      0           40.00
#         1      0      0           25.00
#                1      0           16.00
#                2      0           13.50
#                3      0           32.00
#                4      0           42.50
#                5      0           39.00
#                6      0           41.50
#                9      0             NaN
#         2      0      0           23.00
#                1      0            0.75
#                2      0           18.00
#         3      0      0           32.00
#                1      0            6.00
#                2      0            6.50
#         4      1      0            7.00
#                2      0            7.50
#         5      2      0           10.50
#         8      2      0           14.50
# Name: Age, dtype: float64

# %%
df_all['Age'].fillna(df_all.groupby(['Pclass','SibSp','Parch','Fare_bin'])['Age'].transform('median'),
                     inplace = True)

# %%
df_all[df_all['Age'].isnull()]
# Out:
#              Survived  Pclass                            Name  Sex  Age  \
# PassengerId
# 1234              NaN       3           Sage, Mr. John George    0  NaN
# 1257              NaN       3  Sage, Mrs. John (Annie Bullen)    1  NaN
#
#              SibSp  Parch    Ticket   Fare Cabin  Embarked  Fare_bin
# PassengerId
# 1234             1      9  CA. 2343  69.55   NaN       0.0         0
# 1257             1      9  CA. 2343  69.55   NaN       0.0         0

# %% [markdown]
# The age of this two passengers are not filled because there is no more passengers with its combination of Pclass, SibSp, Parch and Fara. Therefore I will fill them removing SibSp and Parch.

# %%
df_all['Age'].fillna(df_all.groupby(['Pclass','Fare_bin'])['Age'].transform('median'),
                     inplace = True)
df_all.drop('Fare_bin',
           inplace = True,
           axis = 1)

# %% [markdown]
# I drop the binned fare column because I am not sure yet how to use Fare feature in the models.

# %% [markdown]
# #### 2.1.5. Embarked
#
# There are two missing values in embarked feature

# %%
df_all[df_all['Embarked'].isnull()]
# Out:
#              Survived  Pclass                                       Name  Sex  \
# PassengerId
# 62                1.0       1                        Icard, Miss. Amelie    1
# 830               1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)    1
#
#               Age  SibSp  Parch  Ticket  Fare Cabin  Embarked
# PassengerId
# 62           38.0      0      0  113572  80.0   B28       NaN
# 830          62.0      0      0  113572  80.0   B28       NaN

# %% [markdown]
# They happen to have the same ticket number, therefore they should have embarked from the same place. Looking for the names in internet, they did from Southampton, therefore I can replace NaN with a 0.

# %%
df_all['Embarked'].fillna(0, inplace = True)

# %% [markdown]
# #### 2.1.6. Cabin
#
# The next feature to correct is embarked but it shows a 77% of missing values. First we should identify if it is worth to spend time on it.
#
# I will start substituting NaN values with Other.
#
# Also the cabin is compound by a letter and a number. The letter is likely to show the area in the boat and then the number should say specifically the room.
#
# They area where you have the room seems that can be important to survive. Depends on how close it is from the deck or if it is closer to the sinking part of the boat, etc.

# %%
df_all['Cabin'].fillna('Other', inplace = True)

# %%
df_all['Cabin_Letter'] = df_all['Cabin'].str[0]

# %%
df_all_cabin_count = df_all.groupby(['Cabin_Letter']).count()
df_all_cabin_count = df_all_cabin_count['Cabin'].apply(lambda x: 100*x/df_all.shape[0])

df_all_cabin_count.index

plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.barplot(x = df_all_cabin_count.index,
           y = df_all_cabin_count)
# Out:
# <AxesSubplot:xlabel='Cabin_Letter', ylabel='Cabin'>

# %%
df_all_cabin_Pclass_count = df_all.groupby(['Cabin_Letter','Pclass']).count()
df_all_cabin_Pclass_count.reset_index(inplace = True)

Pclass_perc = []
for index, row in df_all_cabin_Pclass_count.iterrows():
    Pclass_perc.append(100*(row['Cabin']/df_all[df_all['Cabin_Letter'] == row['Cabin_Letter']]['Cabin_Letter'].count()))

df_all_cabin_Pclass_count['Cabin_Perc'] = Pclass_perc
    


plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

ax = sns.histplot(df_all_cabin_Pclass_count,
                 x = 'Cabin_Letter',
                 weights = 'Cabin_Perc',
                 hue = 'Pclass',
                 multiple = 'stack',
                 edgecolor = 'white')

# %%
df_all_cabin_Survived_count = df_all.groupby(['Cabin_Letter','Survived']).count()
df_all_cabin_Survived_count.reset_index(inplace = True)

Survived_perc = []
for index, row in df_all_cabin_Survived_count.iterrows():
    Survived_perc.append(100*(row['Cabin']/df_all_cabin_Survived_count[df_all_cabin_Survived_count['Cabin_Letter'] == row['Cabin_Letter']]['Cabin'].sum()))

df_all_cabin_Survived_count['Cabin_Perc'] = Survived_perc
    


plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.histplot(df_all_cabin_Survived_count,
                 x = 'Cabin_Letter',
                 weights = 'Cabin_Perc',
                 hue = 'Survived',
                 multiple = 'stack',
                 edgecolor = 'white')
# Out:
# <AxesSubplot:xlabel='Cabin_Letter', ylabel='Count'>

# %% [markdown]
# We can identify two trends using cabin:
# - The cabin areas are mainly for one class, although there are some combinations.
# - There is a clear correlation between the cabin and survived, for example because of the distance to the deck.
#
# So far, we can leave the NaN as O. In next iterations I may try to improve the definition.
#
# I will map the letters to numbers to be able to include in the exploration later and change T to O as it has just one value and can be misleading.

# %%
cabin_dict = {'A': 0, 'B': 1, 'C': 2,'D': 3, 'E': 4, 'F': 5,'G': 6, 'O': 7, 'T': 7}
df_all['Cabin_Letter'] = df_all['Cabin_Letter'].map(cabin_dict)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1309 entries, 1 to 1309
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Survived      891 non-null    float64
#  1   Pclass        1309 non-null   int64
#  2   Name          1309 non-null   object
#  3   Sex           1309 non-null   int64
#  4   Age           1309 non-null   float64
#  5   SibSp         1309 non-null   int64
#  6   Parch         1309 non-null   int64
#  7   Ticket        1309 non-null   object
#  8   Fare          1309 non-null   float64
#  9   Cabin         1309 non-null   object
#  10  Embarked      1309 non-null   float64
#  11  Cabin_Letter  1309 non-null   int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 132.9+ KB

# %% [markdown]
# Now all the columns are completed, with no NaN values.

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# ### 3.1. Survived

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(df_all['Survived'])
print('In train database {:.2f}% died and {:.2f}% survived'.format(100*df_train['Survived'].value_counts()[1] / df_train.shape[0],
                                                                  100*df_train['Survived'].value_counts()[0] / df_train.shape[0]))
# Out:
# In train database 38.38% died and 61.62% survived
# /home/diego/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# As we can see the train database is slightly unbalanced, 61.62% to 38.38%, we may need to deal with this to improve the results.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.heatmap(df_all.corr(),
           annot = True,
           cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Survived shows a clear correlation with Pclass, Sex, Cabin and Fare, all highly related with the socio-economic status.

# %% [markdown]
# ### 3.2. Pclass
#
# Pclass is a categorical ordinal data. We can study how survived rate is distributed in each class.
#
# Also Pclass show a big correlation with Fare and Age, so we can have a look to see this distribution.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Pclass',
             hue = 'Survived',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# We can see that being on 3rd class you are very likely to not survive, whereas in the other two classes the probabilities are more balanced. Also as it is logical there are many more people in 3rd class than in any other.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Pclass',
            y = 'Age',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# We can see how the median of the first class is the highest with most of the people (25%-75%) between 30 and 50 years old. Not many outlayers, although the extreme quartiles covers almost the whole range because there are some children and elder people.
#
# Second class is similar but with main body of the box slightly younger and the extremes not so spread.
#
# The 3rd class as expected is the youngest one, but without children and babies and just elder people as outliers.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Pclass',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# As expected the higher the class the higher the fare. Although 3rd class is very condensed in a small range, similar than the 2nd class (just slightly more expensive), the 1st class shows bigger spread with some very big outliers.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Pclass',
             hue = 'Embarked',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Most of the people embarking from S and Q ae at 3rd class, whereas more than half of the people embarking from C are mostly in first. This must be reflected in Fare feature.

# %% [markdown]
# ### 3.3. Sex
#
# Sex is a categorical, let's see its distribution regarding survived feature.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Sex',
             hue = 'Survived',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# There are more males (0) than females (0) but there are more survived females than males.
#
# Being a woman, it is very likely to survive, where being a man the probability of dying is quite high.
#
# Let's check the distribution of sex by Pclass.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Sex',
             hue = 'Pclass',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Males are clearly in higher proportion in 3rd class, maybe it has a big influence in the survive rate of males.
#
# Females are quite evenly distributed in the 3 classes, although slightly more in 3rd class.
#
# Let's check its relation with embarkment feature

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Sex',
             hue = 'Embarked',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# As in previous categories, males come from 'S' in a high proportion, then 'C' and lastly 'Q'. It follows the total trend also.
#
# Female shows similar distribution, a bit more even than males.
#
# Now let's check the distribution in cabins.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] == 7].index, axis = 0),
             x = 'Sex',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# I have dropped the category Other from this analysis because it makes very difficult to extract insight, I will study it separatelly.
#
# In general the distribution is very similar, just in Cabin A where there are almost no females and Cabin G, where there are ni males.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] != 7].index, axis = 0),
             x = 'Sex',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# The distribution of sex in category Other (missing Cabin info) is around double of males, what is not so different than the distribution in the boat as a whole. Therefore this does not give us much value.
#
# We can study the sex feature with respect of Parch (number of parents and children).

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Sex',
            y = 'Parch',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Parch'>

# %% [markdown]
# It is interesting that most of the males traveling does not have parents or children in the boat. Females mostly are between 0-2, around 50% travel without children or parents and the other 50% with 1 or 2, I suppose children.
#
# Let's check the distribution with SibSp

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Sex',
            y = 'SibSp',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='SibSp'>

# %% [markdown]
# The distribution is really similar between male and females, it is logical as if the male travels with his spouse, also the female will have that accounted.
#
# Let's study now the Sex feature with respect of Age

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.displot(data = df_all,
            x = 'Age',
            hue = 'Sex',
            palette = 'Paired',
            kind = 'hist',
            kde = True,
            col = 'Survived')

# %% [markdown]
# In this graph we can identify some skewness to the left on died males, most of them were young people in their 20s, where very little under 14-15 died.
#
# Died female shows quite small and flat distribution compared with male one.
#
# Survived male and female looks to be close to a normal distribution both centered in the 25-30s.

# %% [markdown]
# ### 3.3. Age
#
# First we can see the influence of age on survival feature and where it has its most influence.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.displot(data = df_all,
            x = 'Age',
            hue = 'Survived',
            palette = 'Paired',
            kind = 'hist',
            kde = True)

# %% [markdown]
# Both died and survived are slightly skewed to the left, but still children and elder people looks to have a mortality rate close to 50% but between 20 and 40 the probability to die is much higher. Seems that young people stayed longer in the boat helping to evacuate. Also most young people were in 3rd class that also had a high mortality, also because their cabins are more likely to be far from the deck.
#
# Let's see age distribution with respect of parents and children in the boat.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Parch',
            y = 'Age',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Age'>

# %% [markdown]
# The distribution is quite interesting:
# - People traveling without parents or children are mostly in the 20-35.
# - People traveling with 1 parent or children are mainly from 0 to 40, probably a mix of children and young people with one child.
# - People traveling with 2 parents or children are mostly children traveling with its parents.
# - From 3 onwards they seems to be mostly people traveling with its children.
#
# Let's see the distribution with respect of Siblings and Spouse.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'SibSp',
            y = 'Age',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Age'>

# %% [markdown]
# Again it is logical that the people traveling alone or with 1 sibling/spouse is mainly within the range of 20 to 40 because is when the people can travel alone or have just an spouse. But from 2 onwards the age distribution decreases showing that the higher the SibSp the more likely the be younger or even a child.

# %% [markdown]
# ### 3.4. SibSp
#
# Lets study the feature SibSp that shows the amount of siblings or spouse that a passenger is traveling with. Some of the relations has been studied already.
#
# We can start with Cabin_Letter, again I study the Other category separatelly to see if we can get some insight.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] == 7].index, axis = 0),
             x = 'SibSp',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# As most of the Cabins are in the "Other" category, there is not much insight in this graph.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] != 7].index, axis = 0),
             x = 'SibSp',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# Basically, it follows a similar distribution than the SibSp alone, therefore no insight in this graph.
#
# Let's try now with Embarked, maybe families embarked more from a specific port.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Embarked',
             hue = 'SibSp',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
#  Most of the people traveling in family embarked in S.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'SibSp',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='Fare'>

# %% [markdown]
# There is no clear difference in the price of your ticket depending of if you travel alone or with SibSp.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Parch',
             hue = 'SibSp',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %% [markdown]
# It is interesting to see how people traveling without SibSp or with just one is mainly traveling also without children or parents. Aslo that most of the families (Parch>1) are also mainly with 1 or 2 SibSp (just parents or parents plus a sibling).
#
# We can see how Parch and SibSp have more sense when they are looked together, therefor it is possible to join as "family" in feature engineering section.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Pclass',
             hue = 'SibSp',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# It is interesting how most of the families are in 3rd class. Just people traveling alone or with SibSp (I guess spouse) travel in first and second class.

# %% [markdown]
# ### 3.5. Parch
#
# Lets see now Parent and Children feature, I suppose as SibSp it would make more sense if joined.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] == 7].index, axis = 0),
             x = 'Parch',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] != 7].index, axis = 0),
             x = 'Parch',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %% [markdown]
# The result is similar to SibSp, not very insightful as most of the people is in the missing category.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Embarked',
             hue = 'Parch',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Same as with SibSp, most of the families embarked from S

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Parch',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Fare'>

# %% [markdown]
# In this case, it is interesting to see how the people traveling in families pays more. It might be related to Pclass as well.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all,
             x = 'Pclass',
             hue = 'Parch',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# The opposite as expected, most of the families are in 3rd class. Maybe the fare was higher because it was counted as altogether.

# %% [markdown]
# ### 3.6. Fare

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Embarked',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %% [markdown]
# Most of the people embarked at C pays more than the ones embarked at S and Q, this is completely connected with the distribution of Pclass with Embarked.

# %%
plt.figure(figsize = (18,12))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.jointplot(data = df_all,
            x = 'Age',
            y = 'Fare',
            palette = 'Paired',
#            hue = 'Survived',
             height = 8,
             kind = 'reg')

# %% [markdown]
# There is not very clear correlation between fare and age, in general the older the more expensive the ticket is. But low correlated.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Sex',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %% [markdown]
# The females generally pay more for their tickets, although it is also related to the fact that most males were in 3rd class(cheaper) and many females were traveling with children also (sometimes counted ticket together)

# %% [markdown]
# ### 3.7. Embarked

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] == 7].index, axis = 0),
             x = 'Embarked',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] != 7].index, axis = 0),
             x = 'Embarked',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %% [markdown]
# It is interesting that most of the missing cabin people embarked from S, although it was also where most of the people embarked.

# %% [markdown]
# ### 3.8. Cabin

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Cabin_Letter',
            y = 'Age',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Cabin_Letter', ylabel='Age'>

# %% [markdown]
# The missing value cabin seems to cover the whole range of age in a similar distribution.
#
# It is interesting how the 5 first cabins are used by passengers around its 40s but in the number 5 and mainly 6 most are childre.

# %%
plt.figure(figsize = (12,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.boxplot(data = df_all,
            x = 'Cabin_Letter',
            y = 'Fare',
            palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Cabin_Letter', ylabel='Fare'>

# %% [markdown]
# Again, the missing cabin value shows a similar distribution as the whole sample fare but then there is a clear difference between cabin areas and the distribution is really correlated with Pclass as well.
#
# We may be able to do some sort of estimation for cabin letter based on all this parameters.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] == 7].index, axis = 0),
             x = 'Pclass',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# As expected, cabin 6 is fully 3rd class, then 5 is shared between 3 and 2 and the rest are mainly first class.

# %%
plt.figure(figsize = (10,8))
sns.set(font_scale = 1.2)
sns.set_style('ticks')

sns.countplot(data = df_all.drop(df_all[df_all['Cabin_Letter'] != 7].index, axis = 0),
             x = 'Pclass',
             hue = 'Cabin_Letter',
             palette = 'Paired')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Being the missing cabin mostly of 3rd class, i guess most of the people belongs to cabin 5-6.

# %% [markdown]
# ## 4. Save Clean Data

# %%
df_train = df_all[df_all.index <= len(idx_train)]
df_test = df_all[df_all.index > len(idx_train)]

# %%
df_train
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 0.0       3
# 2                 1.0       1
# 3                 1.0       3
# 4                 1.0       1
# 5                 0.0       3
# ...               ...     ...
# 887               0.0       2
# 888               1.0       1
# 889               0.0       3
# 890               1.0       1
# 891               0.0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# ...                                                        ...  ...   ...
# 887                                      Montvila, Rev. Juozas    0  27.0
# 888                               Graham, Miss. Margaret Edith    1  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"    1  13.5
# 890                                      Behr, Mr. Karl Howell    0  26.0
# 891                                        Dooley, Mr. Patrick    0  32.0
#
#              SibSp  Parch            Ticket     Fare  Cabin  Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500  Other       0.0
# 2                1      0          PC 17599  71.2833    C85       1.0
# 3                0      0  STON/O2. 3101282   7.9250  Other       0.0
# 4                1      0            113803  53.1000   C123       0.0
# 5                0      0            373450   8.0500  Other       0.0
# ...            ...    ...               ...      ...    ...       ...
# 887              0      0            211536  13.0000  Other       0.0
# 888              0      0            112053  30.0000    B42       0.0
# 889              1      2        W./C. 6607  23.4500  Other       0.0
# 890              0      0            111369  30.0000   C148       1.0
# 891              0      0            370376   7.7500  Other       2.0
#
#              Cabin_Letter
# PassengerId
# 1                       7
# 2                       2
# 3                       7
# 4                       2
# 5                       7
# ...                   ...
# 887                     7
# 888                     1
# 889                     7
# 890                     2
# 891                     7
#
# [891 rows x 12 columns]

# %%
df_test
# Out:
#              Survived  Pclass  \
# PassengerId
# 892               NaN       3
# 893               NaN       3
# 894               NaN       2
# 895               NaN       3
# 896               NaN       3
# 897               NaN       3
# 898               NaN       3
# 899               NaN       2
# 900               NaN       3
# 901               NaN       3
# 902               NaN       3
# 903               NaN       1
# 904               NaN       1
# 905               NaN       2
# 906               NaN       1
# 907               NaN       2
# 908               NaN       2
# 909               NaN       3
# 910               NaN       3
# 911               NaN       3
# 912               NaN       1
# 913               NaN       3
# 914               NaN       1
# 915               NaN       1
# 916               NaN       1
# 917               NaN       3
# 918               NaN       1
# 919               NaN       3
# 920               NaN       1
# 921               NaN       3
# 922               NaN       2
# 923               NaN       2
# 924               NaN       3
# 925               NaN       3
# 926               NaN       1
# 927               NaN       3
# 928               NaN       3
# 929               NaN       3
# 930               NaN       3
# 931               NaN       3
# 932               NaN       3
# 933               NaN       1
# 934               NaN       3
# 935               NaN       2
# 936               NaN       1
# 937               NaN       3
# 938               NaN       1
# 939               NaN       3
# 940               NaN       1
# 941               NaN       3
# 942               NaN       1
# 943               NaN       2
# 944               NaN       2
# 945               NaN       1
# 946               NaN       2
# 947               NaN       3
# 948               NaN       3
# 949               NaN       3
# 950               NaN       3
# 951               NaN       1
# 952               NaN       3
# 953               NaN       2
# 954               NaN       3
# 955               NaN       3
# 956               NaN       1
# 957               NaN       2
# 958               NaN       3
# 959               NaN       1
# 960               NaN       1
# 961               NaN       1
# 962               NaN       3
# 963               NaN       3
# 964               NaN       3
# 965               NaN       1
# 966               NaN       1
# 967               NaN       1
# 968               NaN       3
# 969               NaN       1
# 970               NaN       2
# 971               NaN       3
# 972               NaN       3
# 973               NaN       1
# 974               NaN       1
# 975               NaN       3
# 976               NaN       2
# 977               NaN       3
# 978               NaN       3
# 979               NaN       3
# 980               NaN       3
# 981               NaN       2
# 982               NaN       3
# 983               NaN       3
# 984               NaN       1
# 985               NaN       3
# 986               NaN       1
# 987               NaN       3
# 988               NaN       1
# 989               NaN       3
# 990               NaN       3
# 991               NaN       3
# 992               NaN       1
# 993               NaN       2
# 994               NaN       3
# 995               NaN       3
# 996               NaN       3
# 997               NaN       3
# 998               NaN       3
# 999               NaN       3
# 1000              NaN       3
# 1001              NaN       2
# 1002              NaN       2
# 1003              NaN       3
# 1004              NaN       1
# 1005              NaN       3
# 1006              NaN       1
# 1007              NaN       3
# 1008              NaN       3
# 1009              NaN       3
# 1010              NaN       1
# 1011              NaN       2
# 1012              NaN       2
# 1013              NaN       3
# 1014              NaN       1
# 1015              NaN       3
# 1016              NaN       3
# 1017              NaN       3
# 1018              NaN       3
# 1019              NaN       3
# 1020              NaN       2
# 1021              NaN       3
# 1022              NaN       3
# 1023              NaN       1
# 1024              NaN       3
# 1025              NaN       3
# 1026              NaN       3
# 1027              NaN       3
# 1028              NaN       3
# 1029              NaN       2
# 1030              NaN       3
# 1031              NaN       3
# 1032              NaN       3
# 1033              NaN       1
# 1034              NaN       1
# 1035              NaN       2
# 1036              NaN       1
# 1037              NaN       3
# 1038              NaN       1
# 1039              NaN       3
# 1040              NaN       1
# 1041              NaN       2
# 1042              NaN       1
# 1043              NaN       3
# 1044              NaN       3
# 1045              NaN       3
# 1046              NaN       3
# 1047              NaN       3
# 1048              NaN       1
# 1049              NaN       3
# 1050              NaN       1
# 1051              NaN       3
# 1052              NaN       3
# 1053              NaN       3
# 1054              NaN       2
# 1055              NaN       3
# 1056              NaN       2
# 1057              NaN       3
# 1058              NaN       1
# 1059              NaN       3
# 1060              NaN       1
# 1061              NaN       3
# 1062              NaN       3
# 1063              NaN       3
# 1064              NaN       3
# 1065              NaN       3
# 1066              NaN       3
# 1067              NaN       2
# 1068              NaN       2
# 1069              NaN       1
# 1070              NaN       2
# 1071              NaN       1
# 1072              NaN       2
# 1073              NaN       1
# 1074              NaN       1
# 1075              NaN       3
# 1076              NaN       1
# 1077              NaN       2
# 1078              NaN       2
# 1079              NaN       3
# 1080              NaN       3
# 1081              NaN       2
# 1082              NaN       2
# 1083              NaN       1
# 1084              NaN       3
# 1085              NaN       2
# 1086              NaN       2
# 1087              NaN       3
# 1088              NaN       1
# 1089              NaN       3
# 1090              NaN       2
# 1091              NaN       3
# 1092              NaN       3
# 1093              NaN       3
# 1094              NaN       1
# 1095              NaN       2
# 1096              NaN       2
# 1097              NaN       1
# 1098              NaN       3
# 1099              NaN       2
# 1100              NaN       1
# 1101              NaN       3
# 1102              NaN       3
# 1103              NaN       3
# 1104              NaN       2
# 1105              NaN       2
# 1106              NaN       3
# 1107              NaN       1
# 1108              NaN       3
# 1109              NaN       1
# 1110              NaN       1
# 1111              NaN       3
# 1112              NaN       2
# 1113              NaN       3
# 1114              NaN       2
# 1115              NaN       3
# 1116              NaN       1
# 1117              NaN       3
# 1118              NaN       3
# 1119              NaN       3
# 1120              NaN       3
# 1121              NaN       2
# 1122              NaN       2
# 1123              NaN       1
# 1124              NaN       3
# 1125              NaN       3
# 1126              NaN       1
# 1127              NaN       3
# 1128              NaN       1
# 1129              NaN       3
# 1130              NaN       2
# 1131              NaN       1
# 1132              NaN       1
# 1133              NaN       2
# 1134              NaN       1
# 1135              NaN       3
# 1136              NaN       3
# 1137              NaN       1
# 1138              NaN       2
# 1139              NaN       2
# 1140              NaN       2
# 1141              NaN       3
# 1142              NaN       2
# 1143              NaN       3
# 1144              NaN       1
# 1145              NaN       3
# 1146              NaN       3
# 1147              NaN       3
# 1148              NaN       3
# 1149              NaN       3
# 1150              NaN       2
# 1151              NaN       3
# 1152              NaN       3
# 1153              NaN       3
# 1154              NaN       2
# 1155              NaN       3
# 1156              NaN       2
# 1157              NaN       3
# 1158              NaN       1
# 1159              NaN       3
# 1160              NaN       3
# 1161              NaN       3
# 1162              NaN       1
# 1163              NaN       3
# 1164              NaN       1
# 1165              NaN       3
# 1166              NaN       3
# 1167              NaN       2
# 1168              NaN       2
# 1169              NaN       2
# 1170              NaN       2
# 1171              NaN       2
# 1172              NaN       3
# 1173              NaN       3
# 1174              NaN       3
# 1175              NaN       3
# 1176              NaN       3
# 1177              NaN       3
# 1178              NaN       3
# 1179              NaN       1
# 1180              NaN       3
# 1181              NaN       3
# 1182              NaN       1
# 1183              NaN       3
# 1184              NaN       3
# 1185              NaN       1
# 1186              NaN       3
# 1187              NaN       3
# 1188              NaN       2
# 1189              NaN       3
# 1190              NaN       1
# 1191              NaN       3
# 1192              NaN       3
# 1193              NaN       2
# 1194              NaN       2
# 1195              NaN       3
# 1196              NaN       3
# 1197              NaN       1
# 1198              NaN       1
# 1199              NaN       3
# 1200              NaN       1
# 1201              NaN       3
# 1202              NaN       3
# 1203              NaN       3
# 1204              NaN       3
# 1205              NaN       3
# 1206              NaN       1
# 1207              NaN       3
# 1208              NaN       1
# 1209              NaN       2
# 1210              NaN       3
# 1211              NaN       2
# 1212              NaN       3
# 1213              NaN       3
# 1214              NaN       2
# 1215              NaN       1
# 1216              NaN       1
# 1217              NaN       3
# 1218              NaN       2
# 1219              NaN       1
# 1220              NaN       2
# 1221              NaN       2
# 1222              NaN       2
# 1223              NaN       1
# 1224              NaN       3
# 1225              NaN       3
# 1226              NaN       3
# 1227              NaN       1
# 1228              NaN       2
# 1229              NaN       3
# 1230              NaN       2
# 1231              NaN       3
# 1232              NaN       2
# 1233              NaN       3
# 1234              NaN       3
# 1235              NaN       1
# 1236              NaN       3
# 1237              NaN       3
# 1238              NaN       2
# 1239              NaN       3
# 1240              NaN       2
# 1241              NaN       2
# 1242              NaN       1
# 1243              NaN       2
# 1244              NaN       2
# 1245              NaN       2
# 1246              NaN       3
# 1247              NaN       1
# 1248              NaN       1
# 1249              NaN       3
# 1250              NaN       3
# 1251              NaN       3
# 1252              NaN       3
# 1253              NaN       2
# 1254              NaN       2
# 1255              NaN       3
# 1256              NaN       1
# 1257              NaN       3
# 1258              NaN       3
# 1259              NaN       3
# 1260              NaN       1
# 1261              NaN       2
# 1262              NaN       2
# 1263              NaN       1
# 1264              NaN       1
# 1265              NaN       2
# 1266              NaN       1
# 1267              NaN       1
# 1268              NaN       3
# 1269              NaN       2
# 1270              NaN       1
# 1271              NaN       3
# 1272              NaN       3
# 1273              NaN       3
# 1274              NaN       3
# 1275              NaN       3
# 1276              NaN       2
# 1277              NaN       2
# 1278              NaN       3
# 1279              NaN       2
# 1280              NaN       3
# 1281              NaN       3
# 1282              NaN       1
# 1283              NaN       1
# 1284              NaN       3
# 1285              NaN       2
# 1286              NaN       3
# 1287              NaN       1
# 1288              NaN       3
# 1289              NaN       1
# 1290              NaN       3
# 1291              NaN       3
# 1292              NaN       1
# 1293              NaN       2
# 1294              NaN       1
# 1295              NaN       1
# 1296              NaN       1
# 1297              NaN       2
# 1298              NaN       2
# 1299              NaN       1
# 1300              NaN       3
# 1301              NaN       3
# 1302              NaN       3
# 1303              NaN       1
# 1304              NaN       3
# 1305              NaN       3
# 1306              NaN       1
# 1307              NaN       3
# 1308              NaN       3
# 1309              NaN       3
#
#                                                           Name  Sex    Age  \
# PassengerId
# 892                                           Kelly, Mr. James    0  34.50
# 893                           Wilkes, Mrs. James (Ellen Needs)    1  47.00
# 894                                  Myles, Mr. Thomas Francis    0  62.00
# 895                                           Wirz, Mr. Albert    0  27.00
# 896               Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.00
# 897                                 Svensson, Mr. Johan Cervin    0  14.00
# 898                                       Connolly, Miss. Kate    1  30.00
# 899                               Caldwell, Mr. Albert Francis    0  26.00
# 900                  Abrahim, Mrs. Joseph (Sophie Halaut Easu)    1  18.00
# 901                                    Davies, Mr. John Samuel    0  21.00
# 902                                           Ilieff, Mr. Ylio    0  25.00
# 903                                 Jones, Mr. Charles Cresson    0  46.00
# 904              Snyder, Mrs. John Pillsbury (Nelle Stevenson)    1  23.00
# 905                                       Howard, Mr. Benjamin    0  63.00
# 906          Chaffee, Mrs. Herbert Fuller (Carrie Constance...    1  47.00
# 907              del Carlo, Mrs. Sebastiano (Argenia Genovesi)    1  24.00
# 908                                          Keane, Mr. Daniel    0  35.00
# 909                                          Assaf, Mr. Gerios    0  21.00
# 910                               Ilmakangas, Miss. Ida Livija    1  27.00
# 911                      Assaf Khalil, Mrs. Mariana (Miriam")"    1  45.00
# 912                                     Rothschild, Mr. Martin    0  55.00
# 913                                  Olsen, Master. Artur Karl    0   9.00
# 914                       Flegenheim, Mrs. Alfred (Antoinette)    1  41.50
# 915                            Williams, Mr. Richard Norris II    0  21.00
# 916            Ryerson, Mrs. Arthur Larned (Emily Maria Borie)    1  48.00
# 917                                    Robins, Mr. Alexander A    0  50.00
# 918                               Ostby, Miss. Helene Ragnhild    1  22.00
# 919                                          Daher, Mr. Shedid    0  22.50
# 920                                    Brady, Mr. John Bertram    0  41.00
# 921                                          Samaan, Mr. Elias    0  23.00
# 922                               Louch, Mr. Charles Alexander    0  50.00
# 923                              Jefferys, Mr. Clifford Thomas    0  24.00
# 924                   Dean, Mrs. Bertram (Eva Georgetta Light)    1  33.00
# 925          Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"    1  13.50
# 926                                   Mock, Mr. Philipp Edmund    0  30.00
# 927           Katavelas, Mr. Vassilios (Catavelas Vassilios")"    0  18.50
# 928                                        Roth, Miss. Sarah A    1  25.00
# 929                                         Cacic, Miss. Manda    1  21.00
# 930                                            Sap, Mr. Julius    0  25.00
# 931                                              Hee, Mr. Ling    0  25.00
# 932                                           Karun, Mr. Franz    0  39.00
# 933                                Franklin, Mr. Thomas Parham    0  41.50
# 934                                      Goldsmith, Mr. Nathan    0  41.00
# 935                      Corbett, Mrs. Walter H (Irene Colvin)    1  30.00
# 936           Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)    1  45.00
# 937                            Peltomaki, Mr. Nikolai Johannes    0  25.00
# 938                                   Chevre, Mr. Paul Romaine    0  45.00
# 939                                   Shaughnessy, Mr. Patrick    0  25.00
# 940            Bucknell, Mrs. William Robert (Emma Eliza Ward)    1  60.00
# 941             Coutts, Mrs. William (Winnie Minnie" Treanor)"    1  36.00
# 942                                   Smith, Mr. Lucien Philip    0  24.00
# 943                                         Pulbaum, Mr. Franz    0  27.00
# 944                              Hocking, Miss. Ellen Nellie""    1  20.00
# 945                                 Fortune, Miss. Ethel Flora    1  28.00
# 946                          Mangiavacchi, Mr. Serafino Emilio    0  30.00
# 947                                       Rice, Master. Albert    0  10.00
# 948                                            Cor, Mr. Bartol    0  35.00
# 949                              Abelseth, Mr. Olaus Jorgensen    0  25.00
# 950                                  Davison, Mr. Thomas Henry    0  25.00
# 951                                Chaudanson, Miss. Victorine    1  36.00
# 952                                            Dika, Mr. Mirko    0  17.00
# 953                                  McCrae, Mr. Arthur Gordon    0  32.00
# 954                               Bjorklund, Mr. Ernst Herbert    0  18.00
# 955                               Bradley, Miss. Bridget Delia    1  22.00
# 956                                Ryerson, Master. John Borie    0  13.00
# 957          Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...    1  30.00
# 958                                    Burns, Miss. Mary Delia    1  18.00
# 959                             Moore, Mr. Clarence Bloomfield    0  47.00
# 960                            Tucker, Mr. Gilbert Milligan Jr    0  31.00
# 961                        Fortune, Mrs. Mark (Mary McDougald)    1  60.00
# 962                                  Mulvihill, Miss. Bertha E    1  24.00
# 963                                         Minkoff, Mr. Lazar    0  21.00
# 964                             Nieminen, Miss. Manta Josefina    1  29.00
# 965                            Ovies y Rodriguez, Mr. Servando    0  28.50
# 966                                       Geiger, Miss. Amalie    1  35.00
# 967                                         Keeping, Mr. Edwin    0  32.50
# 968                                           Miles, Mr. Frank    0  25.00
# 969          Cornell, Mrs. Robert Clifford (Malvina Helen L...    1  55.00
# 970                             Aldworth, Mr. Charles Augustus    0  30.00
# 971                                     Doyle, Miss. Elizabeth    1  24.00
# 972                                       Boulos, Master. Akar    0   6.00
# 973                                         Straus, Mr. Isidor    0  67.00
# 974                                     Case, Mr. Howard Brown    0  49.00
# 975                                       Demetri, Mr. Marinko    0  25.00
# 976                                      Lamb, Mr. John Joseph    0  30.00
# 977                                         Khalil, Mr. Betros    0  25.00
# 978                                         Barry, Miss. Julia    1  27.00
# 979                                 Badman, Miss. Emily Louisa    1  18.00
# 980                                    O'Donoghue, Ms. Bridget    1  25.00
# 981                                Wells, Master. Ralph Lester    0   2.00
# 982          Dyker, Mrs. Adolf Fredrik (Anna Elisabeth Judi...    1  22.00
# 983                                         Pedersen, Mr. Olaf    0  25.00
# 984                       Davidson, Mrs. Thornton (Orian Hays)    1  27.00
# 985                                          Guest, Mr. Robert    0  25.00
# 986                                        Birnbaum, Mr. Jakob    0  25.00
# 987                                 Tenglin, Mr. Gunnar Isidor    0  25.00
# 988          Cavendish, Mrs. Tyrell William (Julia Florence...    1  76.00
# 989                                  Makinen, Mr. Kalle Edvard    0  29.00
# 990                               Braf, Miss. Elin Ester Maria    1  20.00
# 991                               Nancarrow, Mr. William Henry    0  33.00
# 992          Stengel, Mrs. Charles Emil Henry (Annie May Mo...    1  43.00
# 993                                         Weisz, Mr. Leopold    0  27.00
# 994                                         Foley, Mr. William    0  25.00
# 995                     Johansson Palmquist, Mr. Oskar Leander    0  26.00
# 996                  Thomas, Mrs. Alexander (Thamine Thelma")"    1  16.00
# 997                                  Holthen, Mr. Johan Martin    0  28.00
# 998                                        Buckley, Mr. Daniel    0  21.00
# 999                                           Ryan, Mr. Edward    0  25.00
# 1000                          Willer, Mr. Aaron (Abi Weller")"    0  25.00
# 1001                                         Swane, Mr. George    0  18.50
# 1002                                  Stanton, Mr. Samuel Ward    0  41.00
# 1003                                Shine, Miss. Ellen Natalia    1  25.00
# 1004                                  Evans, Miss. Edith Corse    1  36.00
# 1005                                  Buckley, Miss. Katherine    1  18.50
# 1006                    Straus, Mrs. Isidor (Rosalie Ida Blun)    1  63.00
# 1007                               Chronopoulos, Mr. Demetrios    0  18.00
# 1008                                          Thomas, Mr. John    0  25.00
# 1009                           Sandstrom, Miss. Beatrice Irene    1   1.00
# 1010                                      Beattie, Mr. Thomson    0  36.00
# 1011           Chapman, Mrs. John Henry (Sara Elizabeth Lawry)    1  29.00
# 1012                                      Watt, Miss. Bertha J    1  12.00
# 1013                                         Kiernan, Mr. John    0  25.00
# 1014                           Schabert, Mrs. Paul (Emma Mock)    1  35.00
# 1015                                   Carver, Mr. Alfred John    0  28.00
# 1016                                         Kennedy, Mr. John    0  25.00
# 1017                                  Cribb, Miss. Laura Alice    1  17.00
# 1018                                  Brobeck, Mr. Karl Rudolf    0  22.00
# 1019                                       McCoy, Miss. Alicia    1  23.00
# 1020                                      Bowenur, Mr. Solomon    0  42.00
# 1021                                      Petersen, Mr. Marius    0  24.00
# 1022                                   Spinner, Mr. Henry John    0  32.00
# 1023                                 Gracie, Col. Archibald IV    0  53.00
# 1024                             Lefebre, Mrs. Frank (Frances)    1  29.00
# 1025                                     Thomas, Mr. Charles P    0  25.00
# 1026                                    Dintcheff, Mr. Valtcho    0  43.00
# 1027                                 Carlsson, Mr. Carl Robert    0  24.00
# 1028                                 Zakarian, Mr. Mapriededer    0  26.50
# 1029                                       Schmidt, Mr. August    0  26.00
# 1030                                     Drapkin, Miss. Jennie    1  23.00
# 1031                            Goodwin, Mr. Charles Frederick    0  40.00
# 1032                               Goodwin, Miss. Jessie Allis    1  10.00
# 1033                                      Daniels, Miss. Sarah    1  33.00
# 1034                                Ryerson, Mr. Arthur Larned    0  61.00
# 1035                                Beauchamp, Mr. Henry James    0  28.00
# 1036         Lindeberg-Lind, Mr. Erik Gustaf (Mr Edward Lin...    0  42.00
# 1037                                 Vander Planke, Mr. Julius    0  31.00
# 1038                               Hilliard, Mr. Herbert Henry    0  41.50
# 1039                                          Davies, Mr. Evan    0  22.00
# 1040                                 Crafton, Mr. John Bertram    0  41.50
# 1041                                    Lahtinen, Rev. William    0  30.00
# 1042                     Earnshaw, Mrs. Boulton (Olive Potter)    1  23.00
# 1043                                      Matinoff, Mr. Nicola    0  25.00
# 1044                                        Storey, Mr. Thomas    0  60.50
# 1045            Klasen, Mrs. (Hulda Kristina Eugenia Lofqvist)    1  36.00
# 1046                              Asplund, Master. Filip Oscar    0  13.00
# 1047                                      Duquemin, Mr. Joseph    0  24.00
# 1048                                         Bird, Miss. Ellen    1  29.00
# 1049                                  Lundin, Miss. Olga Elida    1  23.00
# 1050                                  Borebank, Mr. John James    0  42.00
# 1051                       Peacock, Mrs. Benjamin (Edith Nile)    1  26.00
# 1052                                        Smyth, Miss. Julia    1  25.00
# 1053                            Touma, Master. Georges Youssef    0   7.00
# 1054                                      Wright, Miss. Marion    1  26.00
# 1055                                        Pearce, Mr. Ernest    0  25.00
# 1056                             Peruschitz, Rev. Joseph Maria    0  41.00
# 1057                Kink-Heilmann, Mrs. Anton (Luise Heilmann)    1  26.00
# 1058                                        Brandeis, Mr. Emil    0  48.00
# 1059                                   Ford, Mr. Edward Watson    0  18.00
# 1060         Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...    1  41.50
# 1061                              Hellstrom, Miss. Hilda Maria    1  22.00
# 1062                                        Lithman, Mr. Simon    0  25.00
# 1063                                       Zakarian, Mr. Ortin    0  27.00
# 1064                                  Dyker, Mr. Adolf Fredrik    0  23.00
# 1065                                          Torfa, Mr. Assad    0  25.00
# 1066                Asplund, Mr. Carl Oscar Vilhelm Gustafsson    0  40.00
# 1067                                 Brown, Miss. Edith Eileen    1  15.00
# 1068                                      Sincock, Miss. Maude    1  20.00
# 1069                           Stengel, Mr. Charles Emil Henry    0  54.00
# 1070          Becker, Mrs. Allen Oliver (Nellie E Baumgardner)    1  36.00
# 1071         Compton, Mrs. Alexander Taylor (Mary Eliza Ing...    1  64.00
# 1072                                 McCrie, Mr. James Matthew    0  30.00
# 1073                          Compton, Mr. Alexander Taylor Jr    0  37.00
# 1074         Marvin, Mrs. Daniel Warner (Mary Graham Carmic...    1  18.00
# 1075                                         Lane, Mr. Patrick    0  25.00
# 1076         Douglas, Mrs. Frederick Charles (Mary Helene B...    1  27.00
# 1077                                 Maybery, Mr. Frank Hubert    0  40.00
# 1078                      Phillips, Miss. Alice Frances Louisa    1  21.00
# 1079                                        Davies, Mr. Joseph    0  17.00
# 1080                                           Sage, Miss. Ada    1  14.50
# 1081                                           Veal, Mr. James    0  40.00
# 1082                                      Angle, Mr. William A    0  34.00
# 1083                                    Salomon, Mr. Abraham L    0  41.50
# 1084                         van Billiard, Master. Walter John    0  11.50
# 1085                                         Lingane, Mr. John    0  61.00
# 1086                             Drew, Master. Marshall Brines    0   8.00
# 1087                         Karlsson, Mr. Julius Konrad Eugen    0  33.00
# 1088                           Spedden, Master. Robert Douglas    0   6.00
# 1089                               Nilsson, Miss. Berta Olivia    1  18.00
# 1090                            Baimbrigge, Mr. Charles Robert    0  23.00
# 1091                   Rasmussen, Mrs. (Lena Jacobsen Solvang)    1  25.00
# 1092                                        Murphy, Miss. Nora    1  25.00
# 1093                   Danbom, Master. Gilbert Sigvard Emanuel    0   0.33
# 1094                                    Astor, Col. John Jacob    0  47.00
# 1095                                Quick, Miss. Winifred Vera    1   8.00
# 1096                                  Andrew, Mr. Frank Thomas    0  25.00
# 1097                                 Omont, Mr. Alfred Fernand    0  41.50
# 1098                                  McGowan, Miss. Katherine    1  35.00
# 1099                              Collett, Mr. Sidney C Stuart    0  24.00
# 1100                             Rosenbaum, Miss. Edith Louise    1  33.00
# 1101                                        Delalic, Mr. Redjo    0  25.00
# 1102                               Andersen, Mr. Albert Karvin    0  32.00
# 1103                                         Finoli, Mr. Luigi    0  25.00
# 1104                                 Deacon, Mr. Percy William    0  17.00
# 1105              Howard, Mrs. Benjamin (Ellen Truelove Arman)    1  60.00
# 1106                    Andersson, Miss. Ida Augusta Margareta    1  38.00
# 1107                                     Head, Mr. Christopher    0  42.00
# 1108                                Mahon, Miss. Bridget Delia    1  25.00
# 1109                                  Wick, Mr. George Dennick    0  57.00
# 1110              Widener, Mrs. George Dunton (Eleanor Elkins)    1  50.00
# 1111                           Thomson, Mr. Alexander Morrison    0  25.00
# 1112                            Duran y More, Miss. Florentina    1  30.00
# 1113                                    Reynolds, Mr. Harold J    0  21.00
# 1114                                Cook, Mrs. (Selena Rogers)    1  22.00
# 1115                             Karlsson, Mr. Einar Gervasius    0  21.00
# 1116          Candee, Mrs. Edward (Helen Churchill Hungerford)    1  53.00
# 1117          Moubarek, Mrs. George (Omine Amenia" Alexander)"    1  26.00
# 1118                                Asplund, Mr. Johan Charles    0  23.00
# 1119                                    McNeill, Miss. Bridget    1  25.00
# 1120                                 Everett, Mr. Thomas James    0  40.50
# 1121                        Hocking, Mr. Samuel James Metcalfe    0  36.00
# 1122                               Sweet, Mr. George Frederick    0  14.00
# 1123                                  Willard, Miss. Constance    1  21.00
# 1124                                   Wiklund, Mr. Karl Johan    0  21.00
# 1125                                      Linehan, Mr. Michael    0  25.00
# 1126                                 Cumings, Mr. John Bradley    0  39.00
# 1127                                    Vendel, Mr. Olof Edvin    0  20.00
# 1128                                  Warren, Mr. Frank Manley    0  64.00
# 1129                                       Baccos, Mr. Raffull    0  20.00
# 1130                                     Hiltunen, Miss. Marta    1  18.00
# 1131               Douglas, Mrs. Walter Donald (Mahala Dutton)    1  48.00
# 1132                 Lindstrom, Mrs. Carl Johan (Sigrid Posse)    1  55.00
# 1133                             Christy, Mrs. (Alice Frances)    1  45.00
# 1134                              Spedden, Mr. Frederic Oakley    0  45.00
# 1135                                        Hyman, Mr. Abraham    0  25.00
# 1136                 Johnston, Master. William Arthur Willie""    0  13.50
# 1137                                   Kenyon, Mr. Frederick R    0  41.00
# 1138                     Karnes, Mrs. J Frank (Claire Bennett)    1  22.00
# 1139                                    Drew, Mr. James Vivian    0  42.00
# 1140                  Hold, Mrs. Stephen (Annie Margaret Hill)    1  29.00
# 1141                 Khalil, Mrs. Betros (Zahie Maria" Elias)"    1  25.00
# 1142                                     West, Miss. Barbara J    1   0.92
# 1143                  Abrahamsson, Mr. Abraham August Johannes    0  20.00
# 1144                                  Clark, Mr. Walter Miller    0  27.00
# 1145                                  Salander, Mr. Karl Johan    0  24.00
# 1146                                       Wenzel, Mr. Linhart    0  32.50
# 1147                                MacKay, Mr. George William    0  25.00
# 1148                                           Mahon, Mr. John    0  25.00
# 1149                                     Niklasson, Mr. Samuel    0  28.00
# 1150                                   Bentham, Miss. Lilian W    1  19.00
# 1151                                  Midtsjo, Mr. Karl Albert    0  21.00
# 1152                      de Messemaeker, Mr. Guillaume Joseph    0  36.50
# 1153                             Nilsson, Mr. August Ferdinand    0  21.00
# 1154         Wells, Mrs. Arthur Henry (Addie" Dart Trevaskis)"    1  29.00
# 1155                              Klasen, Miss. Gertrud Emilia    1   1.00
# 1156                    Portaluppi, Mr. Emilio Ilario Giuseppe    0  30.00
# 1157                                     Lyntakoff, Mr. Stanko    0  25.00
# 1158                     Chisholm, Mr. Roderick Robert Crispin    0  41.50
# 1159                               Warren, Mr. Charles William    0  25.00
# 1160                               Howard, Miss. May Elizabeth    1  25.00
# 1161                                         Pokrnic, Mr. Mate    0  17.00
# 1162                              McCaffry, Mr. Thomas Francis    0  46.00
# 1163                                          Fox, Mr. Patrick    0  25.00
# 1164             Clark, Mrs. Walter Miller (Virginia McDowell)    1  26.00
# 1165                                        Lennon, Miss. Mary    1  25.00
# 1166                                     Saade, Mr. Jean Nassr    0  25.00
# 1167                       Bryhl, Miss. Dagmar Jenny Ingeborg     1  20.00
# 1168                              Parker, Mr. Clifford Richard    0  28.00
# 1169                                     Faunthorpe, Mr. Harry    0  40.00
# 1170                                      Ware, Mr. John James    0  30.00
# 1171                                 Oxenham, Mr. Percy Thomas    0  22.00
# 1172                                    Oreskovic, Miss. Jelka    1  23.00
# 1173                            Peacock, Master. Alfred Edward    0   0.75
# 1174                                     Fleming, Miss. Honora    1  25.00
# 1175                                Touma, Miss. Maria Youssef    1   9.00
# 1176                               Rosblom, Miss. Salli Helena    1   2.00
# 1177                                       Dennis, Mr. William    0  36.00
# 1178                    Franklin, Mr. Charles (Charles Fardon)    0  25.00
# 1179                                Snyder, Mr. John Pillsbury    0  24.00
# 1180                                   Mardirosian, Mr. Sarkis    0  25.00
# 1181                                          Ford, Mr. Arthur    0  25.00
# 1182                       Rheims, Mr. George Alexander Lucien    0  41.50
# 1183                    Daly, Miss. Margaret Marcella Maggie""    1  30.00
# 1184                                         Nasr, Mr. Mustafa    0  25.00
# 1185                                     Dodge, Dr. Washington    0  53.00
# 1186                                 Wittevrongel, Mr. Camille    0  36.00
# 1187                                      Angheloff, Mr. Minko    0  26.00
# 1188                                     Laroche, Miss. Louise    1   1.00
# 1189                                         Samaan, Mr. Hanna    0  23.00
# 1190                                Loring, Mr. Joseph Holland    0  30.00
# 1191                                       Johansson, Mr. Nils    0  29.00
# 1192                                 Olsson, Mr. Oscar Wilhelm    0  32.00
# 1193                                       Malachard, Mr. Noel    0  30.00
# 1194                               Phillips, Mr. Escott Robert    0  43.00
# 1195                                         Pokrnic, Mr. Tome    0  24.00
# 1196                         McCarthy, Miss. Catherine Katie""    1  25.00
# 1197         Crosby, Mrs. Edward Gifford (Catherine Elizabe...    1  64.00
# 1198                      Allison, Mr. Hudson Joshua Creighton    0  30.00
# 1199                                 Aks, Master. Philip Frank    0   0.83
# 1200                                Hays, Mr. Charles Melville    0  55.00
# 1201                Hansen, Mrs. Claus Peter (Jennie L Howard)    1  45.00
# 1202                                      Cacic, Mr. Jego Grga    0  18.00
# 1203                                      Vartanian, Mr. David    0  22.00
# 1204                                       Sadowitz, Mr. Harry    0  25.00
# 1205                                       Carr, Miss. Jeannie    1  37.00
# 1206                     White, Mrs. John Stuart (Ella Holmes)    1  55.00
# 1207                                      Hagardon, Miss. Kate    1  17.00
# 1208                             Spencer, Mr. William Augustus    0  57.00
# 1209                                Rogers, Mr. Reginald Harry    0  19.00
# 1210                                 Jonsson, Mr. Nils Hilding    0  27.00
# 1211                              Jefferys, Mr. Ernest Wilfred    0  22.00
# 1212                               Andersson, Mr. Johan Samuel    0  26.00
# 1213                                     Krekorian, Mr. Neshan    0  25.00
# 1214                                        Nesson, Mr. Israel    0  26.00
# 1215                                        Rowe, Mr. Alfred G    0  33.00
# 1216                                    Kreuchen, Miss. Emilie    1  39.00
# 1217                                            Assam, Mr. Ali    0  23.00
# 1218                              Becker, Miss. Ruth Elizabeth    1  12.00
# 1219               Rosenshine, Mr. George (Mr George Thorne")"    0  46.00
# 1220                             Clarke, Mr. Charles Valentine    0  29.00
# 1221                                       Enander, Mr. Ingvar    0  21.00
# 1222         Davies, Mrs. John Morgan (Elizabeth Agnes Mary...    1  48.00
# 1223                              Dulles, Mr. William Crothers    0  39.00
# 1224                                       Thomas, Mr. Tannous    0  25.00
# 1225                     Nakid, Mrs. Said (Waika Mary" Mowad)"    1  19.00
# 1226                                             Cor, Mr. Ivan    0  27.00
# 1227                                  Maguire, Mr. John Edward    0  30.00
# 1228                                de Brito, Mr. Jose Joaquim    0  32.00
# 1229                                         Elias, Mr. Joseph    0  39.00
# 1230                                      Denbury, Mr. Herbert    0  25.00
# 1231                                     Betros, Master. Seman    0  25.00
# 1232                             Fillbrook, Mr. Joseph Charles    0  18.00
# 1233                                Lundstrom, Mr. Thure Edvin    0  32.00
# 1234                                     Sage, Mr. John George    0  25.00
# 1235         Cardeza, Mrs. James Warburton Martinez (Charlo...    1  58.00
# 1236                       van Billiard, Master. James William    0  16.00
# 1237                               Abelseth, Miss. Karen Marie    1  16.00
# 1238                                Botsford, Mr. William Hull    0  26.00
# 1239           Whabee, Mrs. George Joseph (Shawneene Abi-Saab)    1  38.00
# 1240                                          Giles, Mr. Ralph    0  24.00
# 1241                                    Walcroft, Miss. Nellie    1  31.00
# 1242              Greenfield, Mrs. Leo David (Blanche Strouse)    1  45.00
# 1243                                 Stokes, Mr. Philip Joseph    0  25.00
# 1244                                       Dibden, Mr. William    0  18.00
# 1245                                        Herman, Mr. Samuel    0  49.00
# 1246                   Dean, Miss. Elizabeth Gladys Millvina""    1   0.17
# 1247                                  Julian, Mr. Henry Forbes    0  50.00
# 1248            Brown, Mrs. John Murray (Caroline Lane Lamson)    1  59.00
# 1249                                       Lockyer, Mr. Edward    0  25.00
# 1250                                      O'Keefe, Mr. Patrick    0  25.00
# 1251         Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...    1  30.00
# 1252                               Sage, Master. William Henry    0  14.50
# 1253                   Mallet, Mrs. Albert (Antoinette Magnin)    1  24.00
# 1254              Ware, Mrs. John James (Florence Louise Long)    1  31.00
# 1255                                         Strilic, Mr. Ivan    0  27.00
# 1256              Harder, Mrs. George Achilles (Dorothy Annan)    1  25.00
# 1257                            Sage, Mrs. John (Annie Bullen)    1  25.00
# 1258                                         Caram, Mr. Joseph    0  25.00
# 1259              Riihivouri, Miss. Susanna Juhantytar Sanni""    1  22.00
# 1260                   Gibson, Mrs. Leonard (Pauline C Boeson)    1  45.00
# 1261                             Pallas y Castello, Mr. Emilio    0  29.00
# 1262                                          Giles, Mr. Edgar    0  21.00
# 1263                                 Wilson, Miss. Helen Alice    1  31.00
# 1264                                   Ismay, Mr. Joseph Bruce    0  49.00
# 1265                                    Harbeck, Mr. William H    0  44.00
# 1266                     Dodge, Mrs. Washington (Ruth Vidaver)    1  54.00
# 1267                                  Bowen, Miss. Grace Scott    1  45.00
# 1268                                         Kink, Miss. Maria    1  22.00
# 1269                              Cotterill, Mr. Henry Harry""    0  21.00
# 1270                               Hipkins, Mr. William Edward    0  55.00
# 1271                               Asplund, Master. Carl Edgar    0   5.00
# 1272                                     O'Connor, Mr. Patrick    0  25.00
# 1273                                         Foley, Mr. Joseph    0  26.00
# 1274                                Risien, Mrs. Samuel (Emma)    1  25.00
# 1275                       McNamee, Mrs. Neal (Eileen O'Leary)    1  19.00
# 1276                            Wheeler, Mr. Edwin Frederick""    0  30.00
# 1277                                        Herman, Miss. Kate    1  24.00
# 1278                            Aronsson, Mr. Ernst Axel Algot    0  24.00
# 1279                                           Ashby, Mr. John    0  57.00
# 1280                                      Canavan, Mr. Patrick    0  21.00
# 1281                               Palsson, Master. Paul Folke    0   6.00
# 1282                                Payne, Mr. Vivian Ponsonby    0  23.00
# 1283            Lines, Mrs. Ernest H (Elizabeth Lindsey James)    1  51.00
# 1284                             Abbott, Master. Eugene Joseph    0  13.00
# 1285                                      Gilbert, Mr. William    0  47.00
# 1286                                  Kink-Heilmann, Mr. Anton    0  29.00
# 1287            Smith, Mrs. Lucien Philip (Mary Eloise Hughes)    1  18.00
# 1288                                      Colbert, Mr. Patrick    0  24.00
# 1289         Frolicher-Stehli, Mrs. Maxmillian (Margaretha ...    1  48.00
# 1290                            Larsson-Rondberg, Mr. Edvard A    0  22.00
# 1291                                  Conlon, Mr. Thomas Henry    0  31.00
# 1292                                   Bonnell, Miss. Caroline    1  30.00
# 1293                                           Gale, Mr. Harry    0  38.00
# 1294                            Gibson, Miss. Dorothy Winifred    1  22.00
# 1295                                    Carrau, Mr. Jose Pedro    0  17.00
# 1296                              Frauenthal, Mr. Isaac Gerald    0  43.00
# 1297              Nourney, Mr. Alfred (Baron von Drachstedt")"    0  20.00
# 1298                                 Ware, Mr. William Jeffery    0  23.00
# 1299                                Widener, Mr. George Dunton    0  50.00
# 1300                           Riordan, Miss. Johanna Hannah""    1  25.00
# 1301                                 Peacock, Miss. Treasteall    1   3.00
# 1302                                    Naughton, Miss. Hannah    1  25.00
# 1303           Minahan, Mrs. William Edward (Lillian E Thorpe)    1  37.00
# 1304                            Henriksson, Miss. Jenny Lovisa    1  28.00
# 1305                                        Spector, Mr. Woolf    0  25.00
# 1306                              Oliva y Ocana, Dona. Fermina    1  39.00
# 1307                              Saether, Mr. Simon Sivertsen    0  38.50
# 1308                                       Ware, Mr. Frederick    0  25.00
# 1309                                  Peter, Master. Michael J    0  16.00
#
#              SibSp  Parch              Ticket      Fare            Cabin  \
# PassengerId
# 892              0      0              330911    7.8292            Other
# 893              1      0              363272    7.0000            Other
# 894              0      0              240276    9.6875            Other
# 895              0      0              315154    8.6625            Other
# 896              1      1             3101298   12.2875            Other
# 897              0      0                7538    9.2250            Other
# 898              0      0              330972    7.6292            Other
# 899              1      1              248738   29.0000            Other
# 900              0      0                2657    7.2292            Other
# 901              2      0           A/4 48871   24.1500            Other
# 902              0      0              349220    7.8958            Other
# 903              0      0                 694   26.0000            Other
# 904              1      0               21228   82.2667              B45
# 905              1      0               24065   26.0000            Other
# 906              1      0         W.E.P. 5734   61.1750              E31
# 907              1      0       SC/PARIS 2167   27.7208            Other
# ...
#
#              Embarked  Cabin_Letter
# PassengerId
# 892               2.0             7
# 893               0.0             7
# 894               2.0             7
# 895               0.0             7
# 896               0.0             7
# 897               0.0             7
# 898               2.0             7
# 899               0.0             7
# 900               1.0             7
# 901               0.0             7
# 902               0.0             7
# 903               0.0             7
# 904               0.0             1
# 905               0.0             7
# 906               0.0             4
# 907               1.0             7
# 908               2.0             7
# 909               1.0             7
# 910               0.0             7
# 911               1.0             7
# 912               1.0             7
# 913               0.0             7
# 914               0.0             7
# 915               1.0             7
# 916               1.0             1
# 917               0.0             7
# 918               1.0             1
# 919               1.0             7
# 920               0.0             0
# 921               1.0             7
# 922               0.0             7
# 923               0.0             7
# 924               0.0             7
# 925               0.0             7
# 926               1.0             2
# 927               1.0             7
# 928               0.0             7
# 929               0.0             7
# 930               0.0             7
# 931               0.0             7
# 932               1.0             7
# 933               0.0             3
# 934               0.0             7
# 935               0.0             7
# 936               0.0             3
# 937               0.0             7
# 938               1.0             0
# 939               2.0             7
# 940               1.0             3
# 941               0.0             7
# 942               0.0             2
# 943               1.0             7
# 944               0.0             7
# 945               0.0             2
# 946               1.0             7
# 947               2.0             7
# 948               0.0             7
# 949               0.0             5
# 950               0.0             7
# 951               1.0             1
# 952               0.0             7
# 953               0.0             7
# 954               0.0             7
# 955               2.0             7
# 956               1.0             1
# 957               0.0             7
# 958               2.0             7
# 959               0.0             7
# 960               1.0             2
# 961               0.0             2
# 962               2.0             7
# 963               0.0             7
# 964               0.0             7
# 965               1.0             3
# 966               1.0             2
# 967               1.0             2
# 968               0.0             7
# 969               0.0             2
# 970               0.0             7
# 971               2.0             7
# 972               1.0             7
# 973               0.0             2
# 974               0.0             7
# 975               0.0             7
# 976               2.0             7
# 977               1.0             7
# 978               2.0             7
# 979               0.0             7
# 980               2.0             7
# 981               0.0             7
# 982               0.0             7
# 983               0.0             7
# 984               0.0             1
# 985               0.0             7
# 986               1.0             7
# 987               0.0             7
# 988               0.0             2
# 989               0.0             7
# 990               0.0             7
# 991               0.0             7
# 992               1.0             2
# 993               0.0             7
# 994               2.0             7
# 995               0.0             7
# 996               1.0             7
# 997               0.0             7
# 998               2.0             7
# 999               2.0             7
# 1000              0.0             7
# 1001              0.0             5
# 1002              1.0             7
# 1003              2.0             7
# 1004              1.0             0
# 1005              2.0             7
# 1006              0.0             2
# 1007              1.0             7
# 1008              1.0             7
# 1009              0.0             6
# 1010              1.0             2
# 1011              0.0             7
# 1012              0.0             7
# 1013              2.0             7
# 1014              1.0             2
# 1015              0.0             7
# 1016              2.0             7
# 1017              0.0             7
# 1018              0.0             7
# 1019              2.0             7
# 1020              0.0             7
# 1021              0.0             7
# 1022              0.0             7
# 1023              1.0             2
# 1024              0.0             7
# 1025              1.0             7
# 1026              0.0             7
# 1027              0.0             7
# 1028              1.0             7
# 1029              0.0             7
# 1030              0.0             7
# 1031              0.0             7
# 1032              0.0             7
# 1033              0.0             7
# 1034              1.0             1
# 1035              0.0             7
# 1036              0.0             7
# 1037              0.0             7
# 1038              0.0             4
# 1039              0.0             7
# 1040              0.0             7
# 1041              0.0             7
# 1042              1.0             2
# 1043              1.0             7
# 1044              0.0             7
# 1045              0.0             7
# 1046              0.0             7
# 1047              0.0             7
# 1048              0.0             2
# 1049              0.0             7
# 1050              0.0             3
# 1051              0.0             7
# 1052              2.0             7
# 1053              1.0             7
# 1054              0.0             7
# 1055              0.0             7
# 1056              0.0             7
# 1057              0.0             7
# 1058              1.0             1
# 1059              0.0             7
# 1060              1.0             7
# 1061              0.0             7
# 1062              0.0             7
# 1063              1.0             7
# 1064              0.0             7
# 1065              1.0             7
# 1066              0.0             7
# 1067              0.0             7
# 1068              0.0             7
# 1069              1.0             2
# 1070              0.0             5
# 1071              1.0             4
# 1072              0.0             7
# 1073              1.0             4
# 1074              0.0             3
# 1075              2.0             7
# 1076              1.0             1
# 1077              0.0             7
# 1078              0.0             7
# 1079              0.0             7
# 1080              0.0             7
# 1081              0.0             7
# 1082              0.0             7
# 1083              0.0             7
# 1084              0.0             7
# 1085              2.0             7
# 1086              0.0             7
# 1087              0.0             7
# 1088              1.0             4
# 1089              0.0             7
# 1090              0.0             7
# 1091              0.0             7
# 1092              2.0             7
# 1093              0.0             7
# 1094              1.0             2
# 1095              0.0             7
# 1096              0.0             7
# 1097              1.0             7
# 1098              2.0             7
# 1099              0.0             7
# 1100              1.0             0
# 1101              0.0             7
# 1102              0.0             7
# 1103              0.0             7
# 1104              0.0             7
# 1105              0.0             7
# 1106              0.0             7
# 1107              0.0             1
# 1108              2.0             7
# 1109              0.0             7
# 1110              1.0             2
# 1111              0.0             7
# 1112              1.0             7
# 1113              0.0             7
# 1114              0.0             5
# 1115              0.0             7
# 1116              1.0             7
# 1117              1.0             7
# 1118              0.0             7
# 1119              2.0             7
# 1120              0.0             7
# 1121              0.0             7
# 1122              0.0             7
# 1123              0.0             7
# 1124              0.0             7
# 1125              2.0             7
# 1126              1.0             2
# 1127              0.0             7
# 1128              1.0             3
# 1129              1.0             7
# 1130              0.0             7
# 1131              1.0             2
# 1132              1.0             7
# 1133              0.0             7
# 1134              1.0             4
# 1135              0.0             7
# 1136              0.0             7
# 1137              0.0             3
# 1138              0.0             7
# 1139              0.0             7
# 1140              0.0             7
# 1141              1.0             7
# 1142              0.0             7
# 1143              0.0             7
# 1144              1.0             2
# 1145              0.0             7
# 1146              0.0             7
# 1147              0.0             7
# 1148              2.0             7
# 1149              0.0             7
# 1150              0.0             7
# 1151              0.0             7
# 1152              0.0             7
# 1153              0.0             7
# 1154              0.0             7
# 1155              0.0             7
# 1156              1.0             7
# 1157              0.0             7
# 1158              0.0             7
# 1159              0.0             7
# 1160              0.0             7
# 1161              0.0             7
# 1162              1.0             2
# 1163              2.0             7
# 1164              1.0             2
# 1165              2.0             7
# 1166              1.0             7
# 1167              0.0             7
# 1168              0.0             7
# 1169              0.0             7
# 1170              0.0             7
# 1171              0.0             7
# 1172              0.0             7
# 1173              0.0             7
# 1174              2.0             7
# 1175              1.0             7
# 1176              0.0             7
# 1177              0.0             7
# 1178              0.0             7
# 1179              0.0             1
# 1180              1.0             5
# 1181              0.0             7
# 1182              0.0             7
# 1183              2.0             7
# 1184              1.0             7
# 1185              0.0             0
# 1186              0.0             7
# 1187              0.0             7
# 1188              1.0             7
# 1189              1.0             7
# 1190              0.0             7
# 1191              0.0             7
# 1192              0.0             7
# 1193              1.0             3
# 1194              0.0             7
# 1195              0.0             7
# 1196              2.0             7
# 1197              0.0             1
# 1198              0.0             2
# 1199              0.0             7
# 1200              0.0             1
# 1201              0.0             7
# 1202              0.0             7
# 1203              1.0             7
# 1204              0.0             7
# 1205              2.0             7
# 1206              1.0             2
# 1207              2.0             7
# 1208              1.0             1
# 1209              0.0             7
# 1210              0.0             7
# 1211              0.0             7
# 1212              0.0             7
# 1213              1.0             5
# 1214              0.0             5
# 1215              0.0             7
# 1216              0.0             7
# 1217              0.0             7
# 1218              0.0             5
# 1219              1.0             7
# 1220              0.0             7
# 1221              0.0             7
# 1222              0.0             7
# 1223              1.0             0
# 1224              1.0             7
# 1225              1.0             7
# 1226              0.0             7
# 1227              0.0             2
# 1228              0.0             7
# 1229              1.0             7
# 1230              0.0             7
# 1231              1.0             7
# 1232              0.0             7
# 1233              0.0             7
# 1234              0.0             7
# 1235              1.0             1
# 1236              0.0             7
# 1237              0.0             7
# 1238              0.0             7
# 1239              1.0             7
# 1240              0.0             7
# 1241              0.0             7
# 1242              1.0             3
# 1243              0.0             7
# 1244              0.0             7
# 1245              0.0             7
# 1246              0.0             7
# 1247              0.0             4
# 1248              0.0             2
# 1249              0.0             7
# 1250              2.0             7
# 1251              0.0             7
# 1252              0.0             7
# 1253              1.0             7
# 1254              0.0             7
# 1255              0.0             7
# 1256              1.0             4
# 1257              0.0             7
# 1258              1.0             7
# 1259              0.0             7
# 1260              1.0             7
# 1261              1.0             7
# 1262              0.0             7
# 1263              1.0             4
# 1264              0.0             1
# 1265              0.0             7
# 1266              0.0             0
# 1267              1.0             7
# 1268              0.0             7
# 1269              0.0             7
# 1270              0.0             2
# 1271              0.0             7
# 1272              2.0             7
# 1273              2.0             7
# 1274              0.0             7
# 1275              0.0             7
# 1276              0.0             7
# 1277              0.0             7
# 1278              0.0             7
# 1279              0.0             7
# 1280              2.0             7
# 1281              0.0             7
# 1282              0.0             1
# 1283              0.0             3
# 1284              0.0             7
# 1285              0.0             7
# 1286              0.0             7
# 1287              0.0             2
# 1288              2.0             7
# 1289              1.0             1
# 1290              0.0             7
# 1291              2.0             7
# 1292              0.0             2
# 1293              0.0             7
# 1294              1.0             7
# 1295              0.0             7
# 1296              1.0             3
# 1297              1.0             3
# 1298              0.0             7
# 1299              1.0             2
# 1300              2.0             7
# 1301              0.0             7
# 1302              2.0             7
# 1303              2.0             2
# 1304              0.0             7
# 1305              0.0             7
# 1306              1.0             2
# 1307              0.0             7
# 1308              0.0             7
# 1309              1.0             7

# %%
df_train.to_csv('data/train_clean.csv')
df_test.to_csv('data/test_clean.csv')
