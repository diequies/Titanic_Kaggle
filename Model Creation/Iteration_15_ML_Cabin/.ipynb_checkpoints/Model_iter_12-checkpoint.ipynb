# %% [markdown]
# ## 1. Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate, cross_val_predict

# %% [markdown]
# ## 2. Load Data

# %%
df_train = pd.read_csv('train_iter_11.csv',
                      index_col = 0)
df_test = pd.read_csv('test_iter_11.csv',
                      index_col = 0)

X_train = df_train.drop('Survived',
                       axis = 1,)
Y_train = df_train.loc[:,'Survived']
X_test = df_test.drop('Survived',
                       axis = 1,)

df_best_result = pd.read_csv('../Iteration_9_title/best_result_9.csv',
                             index_col = 0)

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1. Logistic Regression

# %%
#define the model
model = LogisticRegression()

#define the parameters to search
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
class_weight = [None, 'balanced']

#define grid search
grid = dict(solver = solvers,
           penalty = penalty,
           C = c_values,
           class_weight = class_weight)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Best: 0.864191 using {'C': 100, 'class_weight': None, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
df_logistic_results = pd.DataFrame(data = results_dict)
df_logistic_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_logistic_results.reset_index(drop = True,
                               inplace = True)
df_logistic_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 1  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 2  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 3  0.862701  0.040352  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 4  0.862326  0.040275  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 5  0.862326  0.040275  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 6  0.861952  0.040921  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 7  0.861952  0.040507  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 8  0.861952  0.040507  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 9  0.861952  0.040507  {'C': 10, 'class_weight': None, 'penalty': 'l2...

# %%
df_best_result_LR = pd.DataFrame(df_logistic_results.iloc[0,:]).T
df_best_result_LR['Model'] = "Logistic_Regression"
df_best_result_LR
# Out:
#       means      stds                                             params  \
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
#
#                  Model
# 0  Logistic_Regression

# %%
model = LogisticRegression(solver = 'newton-cg',
                           penalty = 'l2',
                           C = 1.0,
                           class_weight = None)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  498   51
# 1   72  270

# %%
df_best_result_LR['Recall'] = model_result['test_recall'].mean()
df_best_result_LR['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LR['Iteration'] = 11
df_best_result_LR['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LR],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.2. Support Vector Machines

# %%
#define the model
model = SVC()

#define the parameters to search
kernel = ['poly','rbf']#['linear','poly','rbf','sigmoid']
c_values = [10,1.0,0.1]#[100, 10, 1.0, 0.1, 0.01]
gamma = ['scale',1.0,0.1]

#define grid search
grid = dict(kernel = kernel,
           C = c_values,
           gamma = gamma)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 18 candidates, totalling 540 fits
# Best: 0.865306 using {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
df_SVC_results = pd.DataFrame(data = results_dict)
df_SVC_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_SVC_results.reset_index(drop = True,
                               inplace = True)
df_SVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.865306  0.032451   {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 1  0.864931  0.032645       {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 2  0.861939  0.030836   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 3  0.861194  0.035452       {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 4  0.860441  0.030669        {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 5  0.860075  0.037455  {'C': 1.0, 'gamma': 'scale', 'kernel': 'poly'}
# 6  0.858573  0.031983    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 7  0.857462  0.037047      {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 8  0.849958  0.036903      {'C': 0.1, 'gamma': 1.0, 'kernel': 'poly'}
# 9  0.841760  0.032557  {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}

# %%
df_best_result_SVM = pd.DataFrame(df_SVC_results.iloc[0,:]).T
df_best_result_SVM['Model'] = "SVC"
df_best_result_SVM
# Out:
#       means      stds                                         params Model
# 0  0.865306  0.032451  {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}   SVC

# %%
model = SVC(kernel = 'rbf',
           C = 1.0,
           gamma = 'scale').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  513   36
# 1   87  255

# %%
df_best_result_SVM['Recall'] = model_result['test_recall'].mean()
df_best_result_SVM['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SVM['Iteration'] = 11
df_best_result_SVM['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SVM],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.3. Naive Bayes Classifiers

# %%
#define the model
model = GaussianNB()

#define the parameters to search
var_smoothing = np.logspace(0, -9, num = 50) 

#define grid search
grid = dict(var_smoothing = var_smoothing)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.812601 using {'var_smoothing': 0.12067926406393285}

# %%
df_GaussianNB_results = pd.DataFrame(data = results_dict)
df_GaussianNB_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_GaussianNB_results.reset_index(drop = True,
                               inplace = True)
df_GaussianNB_results.head(10)
# Out:
#       means      stds                                   params
# 0  0.812601  0.039492   {'var_smoothing': 0.12067926406393285}
# 1  0.809979  0.036243   {'var_smoothing': 0.07906043210907697}
# 2  0.804744  0.039102    {'var_smoothing': 0.0517947467923121}
# 3  0.803987  0.042361  {'var_smoothing': 0.022229964825261943}
# 4  0.801369  0.041884   {'var_smoothing': 0.03393221771895328}
# 5  0.801365  0.041210  {'var_smoothing': 0.014563484775012436}
# 6  0.801003  0.037626    {'var_smoothing': 0.1842069969326716}
# 7  0.800254  0.032650     {'var_smoothing': 0.281176869797423}
# 8  0.793508  0.043740  {'var_smoothing': 0.009540954763499934}
# 9  0.793138  0.035303    {'var_smoothing': 0.4291934260128778}

# %%
df_best_result_GNB = pd.DataFrame(df_GaussianNB_results.iloc[0,:]).T
df_best_result_GNB['Model'] = "GaussianNB"
df_best_result_GNB
# Out:
#       means      stds                                  params       Model
# 0  0.812601  0.039492  {'var_smoothing': 0.12067926406393285}  GaussianNB

# %%
model = GaussianNB(var_smoothing = 0.12067926406393285).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  505   44
# 1  124  218

# %%
df_best_result_GNB['Recall'] = model_result['test_recall'].mean()
df_best_result_GNB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_GNB['Iteration'] = 11
df_best_result_GNB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_GNB],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.5. Perceptron

# %%
#define the model
model = Perceptron()

#define the parameters to search
eta0 = [0.0001,0.001,0.01,0.1,1.0]
max_iter = [10,100,1000,10000]
early_stopping = [True,False]
penalty = ['l2','l1',None]

#define grid search
grid = dict(eta0 = eta0,
           max_iter = max_iter,
           early_stopping = early_stopping,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 120 candidates, totalling 3600 fits
# Best: 0.811411 using {'early_stopping': False, 'eta0': 0.0001, 'max_iter': 10, 'penalty': 'l1'}

# %%
df_Perceptron_results = pd.DataFrame(data = results_dict)
df_Perceptron_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_Perceptron_results.reset_index(drop = True,
                               inplace = True)
df_Perceptron_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 1  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 2  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 3  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 4  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 5  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 6  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 7  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 8  0.808856  0.038162  {'early_stopping': False, 'eta0': 1.0, 'max_it...
# 9  0.807732  0.042375  {'early_stopping': False, 'eta0': 0.1, 'max_it...

# %%
df_best_result_Per = pd.DataFrame(df_Perceptron_results.iloc[0,:]).T
df_best_result_Per['Model'] = "Perceptron"
df_best_result_Per
# Out:
#       means      stds                                             params  \
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
#
#         Model
# 0  Perceptron

# %%
model = Perceptron(eta0 = 0.0001,
           max_iter = 10,
           early_stopping = False,
           penalty = 'l1').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  444  105
# 1   79  263

# %%
df_best_result_Per['Recall'] = model_result['test_recall'].mean()
df_best_result_Per['F1_Score'] = model_result['test_f1'].mean()
df_best_result_Per['Iteration'] = 11
df_best_result_Per['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_Per],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.6. Linear SVC

# %%
#define the model
model = LinearSVC()

#define the parameters to search
c_values = [100, 10, 1.0, 0.1, 0.01]
penalty = ['l2','l1']
max_iter = [1,10,100,1000,10000]

#define grid search
grid = dict(max_iter = max_iter,
           C = c_values,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.867553 using {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
df_LinearSVC_results = pd.DataFrame(data = results_dict)
df_LinearSVC_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_LinearSVC_results.reset_index(drop = True,
                               inplace = True)
df_LinearSVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.867553  0.039931   {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 1  0.866434  0.040136  {'C': 1.0, 'max_iter': 10000, 'penalty': 'l2'}
# 2  0.866434  0.040747  {'C': 100, 'max_iter': 10000, 'penalty': 'l2'}
# 3  0.866063  0.039772   {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 4  0.866059  0.040289    {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# 5  0.864940  0.040567    {'C': 0.1, 'max_iter': 100, 'penalty': 'l2'}
# 6  0.864940  0.040567   {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 7  0.864940  0.040567  {'C': 0.1, 'max_iter': 10000, 'penalty': 'l2'}
# 8  0.864569  0.039654    {'C': 1.0, 'max_iter': 100, 'penalty': 'l2'}
# 9  0.860836  0.041336     {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}

# %%
df_best_result_LSVC = pd.DataFrame(df_LinearSVC_results.iloc[0,:]).T
df_best_result_LSVC['Model'] = "LinearSVC"
df_best_result_LSVC
# Out:
#       means      stds                                         params  \
# 0  0.867553  0.039931  {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
#
#        Model
# 0  LinearSVC

# %%
model = LinearSVC(max_iter = 10000,
           C = 10,
           penalty = 'l2').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#      0    1
# 0  500   49
# 1   71  271

# %%
df_best_result_LSVC['Recall'] = model_result['test_recall'].mean()
df_best_result_LSVC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LSVC['Iteration'] = 11
df_best_result_LSVC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LSVC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.7. Stochastic Gradient Descent

# %%
#define the model
model = SGDClassifier()

#define the parameters to search
loss = ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron', 'squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
penalty = ['l2','l1']
alpha = [0.0001,0.001,0.01,0.1,1]
learning_rate = ['optimal']


#define grid search
grid = dict(loss = loss,
           alpha = alpha,
           penalty = penalty,
           learning_rate = learning_rate)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 90 candidates, totalling 2700 fits
# Best: 0.862701 using {'alpha': 0.001, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}

# %%
df_SGDClassifier_results = pd.DataFrame(data = results_dict)
df_SGDClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_SGDClassifier_results.reset_index(drop = True,
                               inplace = True)
df_SGDClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 1  0.861573  0.039708  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 2  0.861186  0.041518  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 3  0.860828  0.040466  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 4  0.860449  0.032927  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 5  0.860083  0.037759  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 6  0.858947  0.037937  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 7  0.858947  0.039760  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 8  0.858943  0.039039  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 9  0.858198  0.042106  {'alpha': 0.001, 'learning_rate': 'optimal', '...

# %%
df_best_result_SGDC = pd.DataFrame(df_SGDClassifier_results.iloc[0,:]).T
df_best_result_SGDC['Model'] = "SGDClassifier"
df_best_result_SGDC
# Out:
#       means      stds                                             params  \
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
#
#            Model
# 0  SGDClassifier

# %%
model = SGDClassifier(loss = 'log',
                      alpha = 0.001,
                      penalty = 'l1',
                      learning_rate = 'optimal').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  493   56
# 1   68  274

# %%
df_best_result_SGDC['Recall'] = model_result['test_recall'].mean()
df_best_result_SGDC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SGDC['Iteration'] = 11
df_best_result_SGDC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SGDC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           SGDClassifier  0.789496  0.810995         11  0.909375
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.8. Decision Tree

# %%
#define the model
model = DecisionTreeClassifier()

#define the parameters to search
criterion = ['gini', 'entropy']
splitter = ['best','random']
#max_depth = list(range(1,100,10))
min_samples_split = list(range(2,40,2))
min_samples_leaf = list(range(1,20,2))
max_features = ['auto','sqrt','log2', None]

#define grid search
grid = dict(criterion = criterion,
           splitter = splitter,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3040 candidates, totalling 91200 fits
# Best: 0.871677 using {'criterion': 'entropy', 'max_features': None, 'min_samples_leaf': 11, 'min_samples_split': 6, 'splitter': 'random'}

# %%
df_DecisionTreeClassifier_results = pd.DataFrame(data = results_dict)
df_DecisionTreeClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_DecisionTreeClassifier_results.reset_index(drop = True,
                               inplace = True)
df_DecisionTreeClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
# 1  0.871303  0.028625  {'criterion': 'entropy', 'max_features': None,...
# 2  0.871303  0.030059  {'criterion': 'entropy', 'max_features': None,...
# 3  0.871303  0.030338  {'criterion': 'entropy', 'max_features': None,...
# 4  0.871303  0.030476  {'criterion': 'entropy', 'max_features': None,...
# 5  0.871303  0.030614  {'criterion': 'entropy', 'max_features': None,...
# 6  0.870928  0.029923  {'criterion': 'entropy', 'max_features': None,...
# 7  0.870928  0.030618  {'criterion': 'gini', 'max_features': None, 'm...
# 8  0.870179  0.031292  {'criterion': 'gini', 'max_features': None, 'm...
# 9  0.870179  0.030336  {'criterion': 'entropy', 'max_features': None,...

# %%
df_best_result_DTC = pd.DataFrame(df_DecisionTreeClassifier_results.iloc[0,:]).T
df_best_result_DTC['Model'] = "DecisionTreeClassifier"
df_best_result_DTC
# Out:
#       means      stds                                             params  \
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
#
#                     Model
# 0  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'entropy',
                       splitter = 'random',
                       min_samples_split = 6,
                       min_samples_leaf = 11,
                       max_features = None).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  525   24
# 1   88  254

# %%
df_best_result_DTC['Recall'] = model_result['test_recall'].mean()
df_best_result_DTC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_DTC['Iteration'] = 11
df_best_result_DTC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_DTC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0  DecisionTreeClassifier  0.742689  0.819146         11  0.904759
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           SGDClassifier  0.789496  0.810995         11  0.909375
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.9. Random Forest

# %%
#define the model
model = RandomForestClassifier()

#define the parameters to search
n_estimators = [100,1000]
criterion = ['gini','entropy']
max_depth = [100,1000]
#max_depth.append(None)
min_samples_split = [12]
min_samples_leaf = [3,6,9,12,15]
max_features = [None]
bootstrap = [True]

#define grid search
grid = dict(criterion = criterion,
            n_estimators = n_estimators,
           max_depth = max_depth,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features,
           bootstrap = bootstrap)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 40 candidates, totalling 1200 fits
# Best: 0.868681 using {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 12, 'n_estimators': 1000}

# %%
df_RandomForestClassifier_results = pd.DataFrame(data = results_dict)
df_RandomForestClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_RandomForestClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_RandomForestClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.868681  0.029004
# 1  0.867936  0.029064
# 2  0.867932  0.028507
# 3  0.867928  0.031187
# 4  0.867179  0.033147
# 5  0.866434  0.029599
# 6  0.866434  0.030946
# 7  0.866067  0.031174
# 8  0.865689  0.030451
# 9  0.865323  0.028797
#
#                                                                                                                                                        params
# 0  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 12, 'n_estimators': 1000}
# 1  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 1000}
# 2  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 1000}
# 3  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 100}
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 100}
# 5  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 1000}
# 6  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 100}
# 7  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 1000}
# 8  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 1000, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 12, 'n_estimators': 100}
# 9  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 12, 'n_estimators': 100}

# %%
df_best_result_RF = pd.DataFrame(df_RandomForestClassifier_results.iloc[0,:]).T
df_best_result_RF['Model'] = "RandomForestClassifier"
df_best_result_RF
# Out:
#       means      stds                                             params  \
# 0  0.868681  0.029004  {'bootstrap': True, 'criterion': 'entropy', 'm...
#
#                     Model
# 0  RandomForestClassifier

# %%
model = RandomForestClassifier(criterion = 'entropy',
                               n_estimators = 1000,
                               max_depth = 1000,
                               min_samples_split = 12,
                               min_samples_leaf = 6,
                               max_features = None,
                               bootstrap = True).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  507   42
# 1   80  262

# %%
df_best_result_RF['Recall'] = model_result['test_recall'].mean()
df_best_result_RF['F1_Score'] = model_result['test_f1'].mean()
df_best_result_RF['Iteration'] = 11
df_best_result_RF['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_RF],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
# 0  0.868681  0.029004  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0  DecisionTreeClassifier  0.742689  0.819146         11  0.904759
# 0  RandomForestClassifier  0.769076  0.813234         11  0.919214
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           SGDClassifier  0.789496  0.810995         11  0.909375
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.10. XGB Classifier

# %%
#define the model
model = XGBClassifier()

#define the parameters to search
n_estimators = [500]
learning_rate = [0.1,0.01]
max_depth = [6,9]
min_child_weight = [6]
gamma = [0.5,0.7]
subsample = [0.7]
colsample_bytree = [0.5,0.7,0.9]

#define grid search
grid = dict(n_estimators = n_estimators,
           learning_rate = learning_rate,
           max_depth = max_depth,
           min_child_weight = min_child_weight,
           gamma = gamma,
           subsample = subsample,
           colsample_bytree = colsample_bytree,
           use_label_encoder=[False])
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 24 candidates, totalling 720 fits
# [21:09:27] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best: 0.869051 using {'colsample_bytree': 0.9, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}

# %%
df_XGBClassifier_results = pd.DataFrame(data = results_dict)
df_XGBClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_XGBClassifier_results.reset_index(drop = True,
                               inplace = True)

with pd.option_context('display.max_colwidth', -1):     
    display(df_XGBClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.869051  0.031821
# 1  0.868681  0.031911
# 2  0.868681  0.031911
# 3  0.868677  0.031799
# 4  0.868677  0.033349
# 5  0.868302  0.033449
# 6  0.867928  0.033670
# 7  0.867553  0.033385
# 8  0.866808  0.035245
# 9  0.866808  0.035245
#
#                                                                                                                                                                      params
# 0  {'colsample_bytree': 0.9, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 1  {'colsample_bytree': 0.9, 'gamma': 0.7, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 2  {'colsample_bytree': 0.9, 'gamma': 0.7, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 3  {'colsample_bytree': 0.9, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 4  {'colsample_bytree': 0.7, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 5  {'colsample_bytree': 0.7, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 6  {'colsample_bytree': 0.7, 'gamma': 0.7, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 7  {'colsample_bytree': 0.7, 'gamma': 0.7, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 8  {'colsample_bytree': 0.5, 'gamma': 0.5, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}
# 9  {'colsample_bytree': 0.5, 'gamma': 0.7, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 500, 'subsample': 0.7, 'use_label_encoder': False}

# %%
df_best_result_XGB = pd.DataFrame(df_XGBClassifier_results.iloc[0,:]).T
df_best_result_XGB['Model'] = "XGBClassifier"
df_best_result_XGB
# Out:
#       means      stds                                             params  \
# 0  0.869051  0.031821  {'colsample_bytree': 0.9, 'gamma': 0.5, 'learn...
#
#            Model
# 0  XGBClassifier

# %%
model = XGBClassifier(n_estimators = 500,
                       learning_rate = 0.01,
                       max_depth = 9,
                       min_child_weight = 6,
                       gamma = 0.5,
                       subsample = 0.7,
                       colsample_bytree = 0.9,
                       use_label_encoder=[False]).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:49] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:50] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:51] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:53] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:54] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:55] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:55] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:56] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:58] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:58] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:10:59] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:00] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:00] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:01] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:02] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:02] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:11:03] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#      0    1
# 0  513   36
# 1   85  257

# %%
df_best_result_XGB['Recall'] = model_result['test_recall'].mean()
df_best_result_XGB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_XGB['Iteration'] = 11
df_best_result_XGB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_XGB],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
# 0  0.869051  0.031821  {'colsample_bytree': 0.9, 'gamma': 0.5, 'learn...
# 0  0.868681  0.029004  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0  0.842501  0.038236  {'colsample_bytree': 1.0, 'gamma': 0.5, 'learn...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836113  0.032807  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.828643  0.033211  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822655  0.039124         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811814  0.041531  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.811061  0.041889  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.809567  0.043789       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.746708  0.051944  {'early_stopping': False, 'eta0': 0.01, 'max_i...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.721648  0.044861             {'var_smoothing': 0.07906043210907697}
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0  DecisionTreeClassifier  0.742689  0.819146         11  0.904759
# 0           XGBClassifier  0.751513  0.807436         11  0.924661
# 0  RandomForestClassifier  0.769076  0.813234         11  0.919214
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           SGDClassifier  0.789496  0.810995         11  0.909375
# 0           XGBClassifier  0.760588  0.787955          8  0.882208
# 0           XGBClassifier  0.760588  0.787955          7  0.882208
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.771513          8  0.873144
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.722437  0.743198          8  0.838948
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.672437  0.745577          8  0.865672
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.687395  0.731398          8  0.859023
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0           SGDClassifier  0.693193  0.732474          8  0.859319
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690252  0.732484          8  0.859236
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.658403  0.629865          9  0.775928
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.681597  0.619315          8  0.772959
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.476723  0.569235          8  0.808657
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %%
df_best_result[df_best_result['Iteration'].isin([9,11])].sort_values('means',
                                                                   axis = 0,
                                                                   ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.871677  0.031015  {'criterion': 'entropy', 'max_features': None,...
# 0  0.869051  0.031821  {'colsample_bytree': 0.9, 'gamma': 0.5, 'learn...
# 0  0.868681  0.029004  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.867553  0.039931      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.865306  0.032451      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.864191  0.041872  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 0  0.862701  0.039615  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0   0.84248  0.038027  {'colsample_bytree': 0.5, 'gamma': 0.3, 'learn...
# 0  0.837624  0.034895  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.832031  0.034329          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.831652   0.03561        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.831615  0.036464  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.830878  0.039712  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0    0.8234  0.043371  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.812601  0.039492             {'var_smoothing': 0.12067926406393285}
# 0  0.811411  0.042603  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.794241   0.03624             {'var_smoothing': 0.03393221771895328}
# 0  0.764665  0.051891  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0  DecisionTreeClassifier  0.742689  0.819146         11  0.904759
# 0           XGBClassifier  0.751513  0.807436         11  0.924661
# 0  RandomForestClassifier  0.769076  0.813234         11  0.919214
# 0               LinearSVC  0.792353  0.817820         11  0.905937
# 0                     SVC  0.745546  0.802375         11  0.905767
# 0     Logistic_Regression  0.789580  0.814052         11  0.908724
# 0           SGDClassifier  0.789496  0.810995         11  0.909375
# 0           XGBClassifier  0.760336  0.781871          9  0.886201
# 0  RandomForestClassifier  0.728319  0.767401          9  0.872104
# 0                     SVC  0.739580  0.770063          9  0.863637
# 0               LinearSVC  0.748403  0.768142          9  0.867502
# 0     Logistic_Regression  0.766050  0.773831          9  0.867666
# 0           SGDClassifier  0.757395  0.765807          9  0.865314
# 0  DecisionTreeClassifier  0.719244  0.737487          9  0.842602
# 0              GaussianNB  0.637479  0.720472         11  0.866495
# 0              Perceptron  0.769664  0.739130         11  0.872887
# 0              GaussianNB  0.719496  0.721076          9  0.841473
# 0              Perceptron  0.658403  0.629865          9  0.775928

# %% [markdown]
# The new feature showed a generalised improvement.

# %%
df_best_result.to_csv('best_result_11.csv')
