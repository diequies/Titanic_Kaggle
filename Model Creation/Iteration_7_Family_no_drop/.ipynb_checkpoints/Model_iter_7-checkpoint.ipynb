# %% [markdown]
# ## 1. Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate, cross_val_predict

# %% [markdown]
# ## 2. Load Data

# %%
df_train = pd.read_csv('train_iter_7.csv',
                      index_col = 0)
df_test = pd.read_csv('test_iter_7.csv',
                      index_col = 0)

X_train = df_train.drop('Survived',
                       axis = 1,)
Y_train = df_train.loc[:,'Survived']
X_test = df_test

df_best_result = pd.read_csv('../Iteration_6_Family/best_result_6.csv',
                             index_col = 0)

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1. Logistic Regression

# %%
#define the model
model = LogisticRegression()

#define the parameters to search
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
class_weight = [None, 'balanced']

#define grid search
grid = dict(solver = solvers,
           penalty = penalty,
           C = c_values,
           class_weight = class_weight)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Best: 0.812930 using {'C': 0.1, 'class_weight': None, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
df_logistic_results = pd.DataFrame(data = results_dict)
df_logistic_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_logistic_results.reset_index(drop = True,
                               inplace = True)
df_logistic_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.812930  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 1  0.811057  0.044428  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 2  0.811057  0.044428  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 3  0.811057  0.044428  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 4  0.811057  0.044428  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 5  0.810674  0.037200  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 6  0.810674  0.037200  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 7  0.810674  0.037200  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 8  0.810674  0.037200  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 9  0.810674  0.037200  {'C': 1.0, 'class_weight': None, 'penalty': 'l...

# %%
df_best_result_LR = pd.DataFrame(df_logistic_results.iloc[0,:]).T
df_best_result_LR['Model'] = "Logistic_Regression"
df_best_result_LR
# Out:
#      means      stds                                             params  \
# 0  0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
#
#                  Model
# 0  Logistic_Regression

# %%
model = LogisticRegression(solver = 'liblinear',
                           penalty = 'l2',
                           C = 0.1,
                           class_weight = None)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  487   62
# 1  105  237

# %%
df_best_result_LR['Recall'] = model_result['test_recall'].mean()
df_best_result_LR['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LR['Iteration'] = 7
df_best_result_LR['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LR],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.2. Support Vector Machines

# %%
#define the model
model = SVC()

#define the parameters to search
kernel = ['poly','rbf']#['linear','poly','rbf','sigmoid']
c_values = [10,1.0]#[100, 10, 1.0, 0.1, 0.01]
gamma = ['scale', 0.1]

#define grid search
grid = dict(kernel = kernel,
           C = c_values,
           gamma = gamma)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 8 candidates, totalling 240 fits
# Best: 0.821910 using {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}

# %%
df_SVC_results = pd.DataFrame(data = results_dict)
df_SVC_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_SVC_results.reset_index(drop = True,
                               inplace = True)
df_SVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.821910  0.038503      {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 1  0.819297  0.036174   {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 2  0.818922  0.035290       {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 3  0.817424  0.036833  {'C': 1.0, 'gamma': 'scale', 'kernel': 'poly'}
# 4  0.815156  0.039098        {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# 5  0.814411  0.039525       {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 6  0.814395  0.039552   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 7  0.812905  0.039295    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
df_best_result_SVM = pd.DataFrame(df_SVC_results.iloc[0,:]).T
df_best_result_SVM['Model'] = "SVC"
df_best_result_SVM
# Out:
#      means      stds                                      params Model
# 0  0.82191  0.038503  {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}   SVC

# %%
model = SVC(kernel = 'poly',
           C = 1.0,
           gamma = 0.1).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  502   47
# 1  113  229

# %%
df_best_result_SVM['Recall'] = model_result['test_recall'].mean()
df_best_result_SVM['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SVM['Iteration'] = 7
df_best_result_SVM['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SVM],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.3. Naive Bayes Classifiers

# %%
#define the model
model = GaussianNB()

#define the parameters to search
var_smoothing = np.logspace(0, -9, num = 50) 

#define grid search
grid = dict(var_smoothing = var_smoothing)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.713038 using {'var_smoothing': 0.03393221771895328}

# %%
df_GaussianNB_results = pd.DataFrame(data = results_dict)
df_GaussianNB_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_GaussianNB_results.reset_index(drop = True,
                               inplace = True)
df_GaussianNB_results.head(10)
# Out:
#       means      stds                                    params
# 0  0.713038  0.041607    {'var_smoothing': 0.03393221771895328}
# 1  0.712692  0.038110      {'var_smoothing': 0.281176869797423}
# 2  0.712285  0.041316    {'var_smoothing': 0.07906043210907697}
# 3  0.711581  0.035425     {'var_smoothing': 0.4291934260128778}
# 4  0.711540  0.041361     {'var_smoothing': 0.0517947467923121}
# 5  0.711165  0.042645    {'var_smoothing': 0.12067926406393285}
# 6  0.710046  0.042942  {'var_smoothing': 0.0062505519252739694}
# 7  0.709297  0.042973   {'var_smoothing': 0.009540954763499934}
# 8  0.709297  0.042678   {'var_smoothing': 0.004094915062380423}
# 9  0.709297  0.042777  {'var_smoothing': 0.0004941713361323833}

# %%
df_best_result_GNB = pd.DataFrame(df_GaussianNB_results.iloc[0,:]).T
df_best_result_GNB['Model'] = "GaussianNB"
df_best_result_GNB
# Out:
#       means      stds                                  params       Model
# 0  0.713038  0.041607  {'var_smoothing': 0.03393221771895328}  GaussianNB

# %%
model = GaussianNB(var_smoothing = 0.03393221771895328).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  480   69
# 1  187  155

# %%
df_best_result_GNB['Recall'] = model_result['test_recall'].mean()
df_best_result_GNB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_GNB['Iteration'] = 7
df_best_result_GNB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_GNB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.5. Perceptron

# %%
#define the model
model = Perceptron()

#define the parameters to search
eta0 = [0.0001,0.001,0.01,0.1,1.0]
max_iter = [10,100,1000,10000]
early_stopping = [True,False]
penalty = ['l2','l1',None]

#define grid search
grid = dict(eta0 = eta0,
           max_iter = max_iter,
           early_stopping = early_stopping,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 120 candidates, totalling 3600 fits
# Best: 0.736625 using {'early_stopping': False, 'eta0': 0.0001, 'max_iter': 10, 'penalty': 'l2'}

# %%
df_Perceptron_results = pd.DataFrame(data = results_dict)
df_Perceptron_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_Perceptron_results.reset_index(drop = True,
                               inplace = True)
df_Perceptron_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 1  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 2  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 3  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 4  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 5  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 6  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 7  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 8  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 9  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.001, 'max_...

# %%
df_best_result_Per = pd.DataFrame(df_Perceptron_results.iloc[0,:]).T
df_best_result_Per['Model'] = "Perceptron"
df_best_result_Per
# Out:
#       means      stds                                             params  \
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
#
#         Model
# 0  Perceptron

# %%
model = Perceptron(eta0 = 0.0001,
           max_iter = 10,
           early_stopping = False,
           penalty = 'l2').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  367  182
# 1   89  253

# %%
df_best_result_Per['Recall'] = model_result['test_recall'].mean()
df_best_result_Per['F1_Score'] = model_result['test_f1'].mean()
df_best_result_Per['Iteration'] = 7
df_best_result_Per['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_Per],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.6. Linear SVC

# %%
#define the model
model = LinearSVC()

#define the parameters to search
c_values = [100, 10, 1.0, 0.1, 0.01]
penalty = ['l2','l1']
max_iter = [1,10,100,1000,10000]

#define grid search
grid = dict(max_iter = max_iter,
           C = c_values,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.808435 using {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
df_LinearSVC_results = pd.DataFrame(data = results_dict)
df_LinearSVC_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_LinearSVC_results.reset_index(drop = True,
                               inplace = True)
df_LinearSVC_results.head(10)
# Out:
#       means      stds                                           params
# 0  0.808435  0.043468     {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 1  0.808435  0.043468    {'C': 0.01, 'max_iter': 100, 'penalty': 'l2'}
# 2  0.808435  0.043468   {'C': 0.01, 'max_iter': 1000, 'penalty': 'l2'}
# 3  0.808435  0.043468  {'C': 0.01, 'max_iter': 10000, 'penalty': 'l2'}
# 4  0.801694  0.039242     {'C': 0.1, 'max_iter': 100, 'penalty': 'l2'}
# 5  0.801694  0.039242    {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 6  0.801694  0.039242   {'C': 0.1, 'max_iter': 10000, 'penalty': 'l2'}
# 7  0.801298  0.046186      {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 8  0.799072  0.042061      {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 9  0.798693  0.039980   {'C': 100, 'max_iter': 10000, 'penalty': 'l2'}

# %%
df_best_result_LSVC = pd.DataFrame(df_LinearSVC_results.iloc[0,:]).T
df_best_result_LSVC['Model'] = "LinearSVC"
df_best_result_LSVC
# Out:
#       means      stds                                        params      Model
# 0  0.808435  0.043468  {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}  LinearSVC

# %%
model = LinearSVC(max_iter = 10,
           C = 0.01,
           penalty = 'l2').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#      0    1
# 0  485   64
# 1  107  235

# %%
df_best_result_LSVC['Recall'] = model_result['test_recall'].mean()
df_best_result_LSVC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LSVC['Iteration'] = 7
df_best_result_LSVC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LSVC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.7. Stochastic Gradient Descent

# %%
#define the model
model = SGDClassifier()

#define the parameters to search
loss = ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron', 'squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
penalty = ['l2','l1']
alpha = [0.0001,0.001,0.01,0.1,1]
learning_rate = ['optimal']


#define grid search
grid = dict(loss = loss,
           alpha = alpha,
           penalty = penalty,
           learning_rate = learning_rate)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 90 candidates, totalling 2700 fits
# Best: 0.812551 using {'alpha': 0.01, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}

# %%
df_SGDClassifier_results = pd.DataFrame(data = results_dict)
df_SGDClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_SGDClassifier_results.reset_index(drop = True,
                               inplace = True)
df_SGDClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 1  0.808419  0.039672  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 2  0.806588  0.042662  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 3  0.804320  0.036948  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 4  0.801319  0.044017  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 5  0.799467  0.040588  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 6  0.798714  0.042563  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 7  0.792730  0.038371  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 8  0.791248  0.038733  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 9  0.790849  0.047051  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...

# %%
df_best_result_SGDC = pd.DataFrame(df_SGDClassifier_results.iloc[0,:]).T
df_best_result_SGDC['Model'] = "SGDClassifier"
df_best_result_SGDC
# Out:
#       means      stds                                             params  \
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
#
#            Model
# 0  SGDClassifier

# %%
model = SGDClassifier(loss = 'log',
                      alpha = 0.01,
                      penalty = 'l2',
                      learning_rate = 'optimal').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  485   64
# 1  106  236

# %%
df_best_result_SGDC['Recall'] = model_result['test_recall'].mean()
df_best_result_SGDC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SGDC['Iteration'] = 7
df_best_result_SGDC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SGDC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.8. Decision Tree

# %%
#define the model
model = DecisionTreeClassifier()

#define the parameters to search
criterion = ['gini', 'entropy']
splitter = ['best','random']
#max_depth = list(range(1,100,10))
min_samples_split = list(range(2,40,2))
min_samples_leaf = list(range(1,20,2))
max_features = ['auto','sqrt','log2', None]

#define grid search
grid = dict(criterion = criterion,
           splitter = splitter,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3040 candidates, totalling 91200 fits
# Best: 0.826787 using {'criterion': 'gini', 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 10, 'splitter': 'best'}

# %%
df_DecisionTreeClassifier_results = pd.DataFrame(data = results_dict)
df_DecisionTreeClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_DecisionTreeClassifier_results.reset_index(drop = True,
                               inplace = True)
df_DecisionTreeClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 1  0.824540  0.034564  {'criterion': 'gini', 'max_features': None, 'm...
# 2  0.823762  0.044469  {'criterion': 'gini', 'max_features': None, 'm...
# 3  0.823042  0.036463  {'criterion': 'gini', 'max_features': None, 'm...
# 4  0.822672  0.038276  {'criterion': 'entropy', 'max_features': None,...
# 5  0.822667  0.039214  {'criterion': 'gini', 'max_features': None, 'm...
# 6  0.822659  0.041187  {'criterion': 'entropy', 'max_features': None,...
# 7  0.822297  0.038744  {'criterion': 'gini', 'max_features': None, 'm...
# 8  0.821174  0.037790  {'criterion': 'entropy', 'max_features': None,...
# 9  0.820795  0.040958  {'criterion': 'entropy', 'max_features': None,...

# %%
df_best_result_DTC = pd.DataFrame(df_DecisionTreeClassifier_results.iloc[0,:]).T
df_best_result_DTC['Model'] = "DecisionTreeClassifier"
df_best_result_DTC
# Out:
#       means      stds                                             params  \
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
#
#                     Model
# 0  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'gini',
                       splitter = 'best',
                       min_samples_split = 10,
                       min_samples_leaf = 5,
                       max_features = None).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  478   71
# 1   92  250

# %%
df_best_result_DTC['Recall'] = model_result['test_recall'].mean()
df_best_result_DTC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_DTC['Iteration'] = 7
df_best_result_DTC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_DTC],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.9. Random Forest

# %%
#define the model
model = RandomForestClassifier()

#define the parameters to search
n_estimators = [100,1000]
criterion = ['gini','entropy']
max_depth = [10,100]
#max_depth.append(None)
min_samples_split = [4,6,8]
min_samples_leaf = [1,3,5]
max_features = [None]
bootstrap = [True, False]

#define grid search
grid = dict(criterion = criterion,
            n_estimators = n_estimators,
           max_depth = max_depth,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features,
           bootstrap = bootstrap)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 144 candidates, totalling 4320 fits
# Best: 0.836862 using {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}

# %%
df_RandomForestClassifier_results = pd.DataFrame(data = results_dict)
df_RandomForestClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_RandomForestClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_RandomForestClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.836862  0.032330
# 1  0.836117  0.035646
# 2  0.836109  0.033345
# 3  0.834619  0.030323
# 4  0.834619  0.031945
# 5  0.834245  0.031914
# 6  0.834232  0.034748
# 7  0.833878  0.034753
# 8  0.833874  0.033634
# 9  0.833862  0.032174
#
#                                                                                                                                                      params
# 0  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 1  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 2  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 1000}
# 3  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 1000}
# 4  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 1000}
# 5  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 1000}
# 6  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 1000}
# 7  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 100}
# 8  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 1000}
# 9  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 100}

# %%
df_best_result_RF = pd.DataFrame(df_RandomForestClassifier_results.iloc[0,:]).T
df_best_result_RF['Model'] = "RandomForestClassifier"
df_best_result_RF
# Out:
#       means     stds                                             params  \
# 0  0.836862  0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
#
#                     Model
# 0  RandomForestClassifier

# %%
model = RandomForestClassifier(criterion = 'entropy',
                               n_estimators = 100,
                               max_depth = 100,
                               min_samples_split = 4,
                               min_samples_leaf = 3,
                               max_features = None,
                               bootstrap = True).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  492   57
# 1   91  251

# %%
df_best_result_RF['Recall'] = model_result['test_recall'].mean()
df_best_result_RF['F1_Score'] = model_result['test_f1'].mean()
df_best_result_RF['Iteration'] = 7
df_best_result_RF['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_RF],
         axis = 0)

# %%
pd.set_option('display.max_rows', 999)
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836862   0.03233  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826787  0.036212  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0   0.82191  0.038503         {'C': 1.0, 'gamma': 0.1, 'kernel': 'poly'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0   0.81293  0.043776  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.812551  0.044531  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808435  0.043468       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.736625  0.040254  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.713038  0.041607             {'var_smoothing': 0.03393221771895328}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.742773  0.775271          7  0.870719
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.722521  0.745643          7  0.835114
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0                     SVC  0.669580  0.738648          7  0.871017
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.738252          7  0.856517
# 0           SGDClassifier  0.701765  0.734932          7  0.857952
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.687143  0.731642          7  0.857044
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.740588  0.646469          7  0.794324
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.453277  0.542999          7  0.805879
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.10. XGB Classifier

# %%
#define the model
model = XGBClassifier()

#define the parameters to search
n_estimators = [2000]
learning_rate = [0.1,0.01]
max_depth = [6,9]
min_child_weight = [3,6,9]
gamma = [1]
subsample = [1.0]
colsample_bytree = [1.0]

#define grid search
grid = dict(n_estimators = n_estimators,
           learning_rate = learning_rate,
           max_depth = max_depth,
           min_child_weight = min_child_weight,
           gamma = gamma,
           subsample = subsample,
           colsample_bytree = colsample_bytree,
           use_label_encoder=[False])
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 12 candidates, totalling 360 fits
# [10:43:10] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best: 0.841748 using {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_XGBClassifier_results = pd.DataFrame(data = results_dict)
df_XGBClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_XGBClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_XGBClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.841748  0.035564
# 1  0.840633  0.035968
# 2  0.839871  0.033974
# 3  0.837628  0.036562
# 4  0.834640  0.037210
# 5  0.833887  0.032760
# 6  0.833516  0.033218
# 7  0.833512  0.036128
# 8  0.833146  0.036851
# 9  0.832763  0.034474
#
#                                                                                                                                                                     params
# 0  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 1  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 2  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 3  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 4  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 5  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 9, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 6  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 9, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 7  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 8  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 9  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 6, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_best_result_XGB = pd.DataFrame(df_XGBClassifier_results.iloc[0,:]).T
df_best_result_XGB['Model'] = "XGBClassifier"
df_best_result_XGB
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
#
#            Model
# 0  XGBClassifier

# %%
model = XGBClassifier(n_estimators = 2000,
                       learning_rate = 0.01,
                       max_depth = 9,
                       min_child_weight = 6,
                       gamma = 1.0,
                       subsample = 1.0,
                       colsample_bytree = 1.0,
                       use_label_encoder=[False]).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:40] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:43] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:44] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:46] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:48] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:49] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:51] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:54] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:56] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:44:59] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:01] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:02] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:04] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:05] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:07] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:08] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:10] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:12] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [10:45:13] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#      0    1
# 0  500   49
# 1   94  248

# %%
df_best_result_XGB['Recall'] = model_result['test_recall'].mean()
df_best_result_XGB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_XGB['Iteration'] = 6
df_best_result_XGB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_XGB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          4  0.810037
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %%
df_best_result[df_best_result['Iteration'].isin([2,5,6])].sort_values('means',
                                                                   axis = 0,
                                                                   ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.841748  0.035564  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.837611  0.033098  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.836126  0.038454  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.835372  0.031847  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.826783  0.033091  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.824553   0.03489  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.822285  0.037868          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820433  0.037673          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.811806  0.043815  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.810283  0.033558  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.809925  0.043785  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.808069  0.040754        {'C': 0.01, 'max_iter': 1, 'penalty': 'l2'}
# 0  0.808065  0.042223  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.804336  0.039427       {'C': 0.01, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0   0.76092  0.038731  {'early_stopping': True, 'eta0': 0.001, 'max_i...
# 0  0.751939   0.05393  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.714157  0.039457             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
# 0  0.712289  0.039842             {'var_smoothing': 0.07906043210907697}
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.725546  0.771451          6  0.879804
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0  RandomForestClassifier  0.731092  0.777132          6  0.864891
# 0           XGBClassifier  0.710840  0.763086          5  0.876457
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.725294  0.770897          5  0.867502
# 0  DecisionTreeClassifier  0.725462  0.748269          6  0.838959
# 0  DecisionTreeClassifier  0.731345  0.748041          5  0.834424
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0                     SVC  0.719160  0.752776          6  0.857880
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0                     SVC  0.716303  0.748823          5  0.863954
# 0     Logistic_Regression  0.693025  0.739383          5  0.856677
# 0           SGDClassifier  0.710672  0.730832          6  0.852596
# 0           SGDClassifier  0.701849  0.737289          5  0.857382
# 0               LinearSVC  0.690420  0.720416          5  0.849114
# 0     Logistic_Regression  0.698908  0.739599          6  0.857771
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0               LinearSVC  0.696050  0.732404          6  0.858931
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.728319  0.633645          6  0.797566
# 0              Perceptron  0.728739  0.664537          5  0.792099
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              GaussianNB  0.429832  0.531893          6  0.811129
# 0              GaussianNB  0.432773  0.531529          5  0.810037
# 0              GaussianNB  0.432773  0.531529          5  0.810037

# %% [markdown]
# Iteration 6 is consistently better in most of the models.

# %%
df_best_result.to_csv('best_result_6.csv')
