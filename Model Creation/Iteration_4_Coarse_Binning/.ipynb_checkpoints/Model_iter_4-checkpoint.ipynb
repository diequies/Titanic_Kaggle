# %% [markdown]
# ## 1. Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate, cross_val_predict

# %% [markdown]
# ## 2. Load Data

# %%
df_train = pd.read_csv('train_iter_4.csv',
                      index_col = 0)
df_test = pd.read_csv('test_iter_4.csv',
                      index_col = 0)

X_train = df_train.drop('Survived',
                       axis = 1,)
Y_train = df_train.loc[:,'Survived']
X_test = df_test

df_best_result = pd.read_csv('../Iteration_3_Normalization/best_result_3.csv',
                             index_col = 0)

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1. Logistic Regression

# %%
#define the model
model = LogisticRegression()

#define the parameters to search
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
class_weight = [None, 'balanced']

#define grid search
grid = dict(solver = solvers,
           penalty = penalty,
           C = c_values,
           class_weight = class_weight)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Best: 0.804707 using {'C': 0.01, 'class_weight': None, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
df_logistic_results = pd.DataFrame(data = results_dict)
df_logistic_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_logistic_results.reset_index(drop = True,
                               inplace = True)
df_logistic_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 1  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 2  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 3  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 4  0.797224  0.038705  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 5  0.796841  0.039231  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 6  0.796841  0.039231  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 7  0.796841  0.039231  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 8  0.796841  0.039231  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 9  0.796841  0.039231  {'C': 10, 'class_weight': None, 'penalty': 'l2...

# %%
df_best_result_LR = pd.DataFrame(df_logistic_results.iloc[0,:]).T
df_best_result_LR['Model'] = "Logistic_Regression"
df_best_result_LR
# Out:
#       means      stds                                             params  \
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
#
#                  Model
# 0  Logistic_Regression

# %%
model = LogisticRegression(solver = 'newton-cg',
                           penalty = 'l2',
                           C = 0.01,
                           class_weight = None)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  495   54
# 1  122  220

# %%
df_best_result_LR['Recall'] = model_result['test_recall'].mean()
df_best_result_LR['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LR['Iteration'] = 4
df_best_result_LR['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LR],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.2. Support Vector Machines

# %%
#define the model
model = SVC()

#define the parameters to search
kernel = ['poly','rbf']#['linear','poly','rbf','sigmoid']
c_values = [10,1.0,0.1]#[100, 10, 1.0, 0.1, 0.01]
gamma = ['scale', 1, 0.1, 0.01, 0.001]

#define grid search
grid = dict(kernel = kernel,
           C = c_values,
           gamma = gamma)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best: 0.816667 using {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
df_SVC_results = pd.DataFrame(data = results_dict)
df_SVC_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_SVC_results.reset_index(drop = True,
                               inplace = True)
df_SVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.816667  0.040291   {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 1  0.816305  0.037889       {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 2  0.812942  0.039806       {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# 3  0.810695  0.031762  {'C': 1.0, 'gamma': 'scale', 'kernel': 'poly'}
# 4  0.810691  0.043028   {'C': 0.1, 'gamma': 'scale', 'kernel': 'rbf'}
# 5  0.808069  0.043866       {'C': 0.1, 'gamma': 0.1, 'kernel': 'rbf'}
# 6  0.806950  0.034042       {'C': 10, 'gamma': 0.1, 'kernel': 'poly'}
# 7  0.806180  0.043775        {'C': 0.1, 'gamma': 1, 'kernel': 'poly'}
# 8  0.805077  0.037306         {'C': 1.0, 'gamma': 1, 'kernel': 'rbf'}
# 9  0.804336  0.033039   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}

# %%
df_best_result_SVM = pd.DataFrame(df_SVC_results.iloc[0,:]).T
df_best_result_SVM['Model'] = "SVC"
df_best_result_SVM
# Out:
#       means      stds                                         params Model
# 0  0.816667  0.040291  {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}   SVC

# %%
model = SVC(kernel = 'rbf',
           C = 1.0,
           gamma = 'scale').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  504   45
# 1  120  222

# %%
df_best_result_SVM['Recall'] = model_result['test_recall'].mean()
df_best_result_SVM['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SVM['Iteration'] = 4
df_best_result_SVM['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SVM],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.3. Naive Bayes Classifiers

# %%
#define the model
model = GaussianNB()

#define the parameters to search
var_smoothing = np.logspace(0, -9, num = 50) 

#define grid search
grid = dict(var_smoothing = var_smoothing)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.779630 using {'var_smoothing': 0.0517947467923121}

# %%
df_GaussianNB_results = pd.DataFrame(data = results_dict)
df_GaussianNB_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_GaussianNB_results.reset_index(drop = True,
                               inplace = True)
df_GaussianNB_results.head(10)
# Out:
#       means      stds                                    params
# 0  0.779630  0.037600     {'var_smoothing': 0.0517947467923121}
# 1  0.778514  0.035067    {'var_smoothing': 0.07906043210907697}
# 2  0.778502  0.040153   {'var_smoothing': 0.022229964825261943}
# 3  0.777757  0.038487    {'var_smoothing': 0.03393221771895328}
# 4  0.777395  0.033356    {'var_smoothing': 0.12067926406393285}
# 5  0.777378  0.040696   {'var_smoothing': 0.014563484775012436}
# 6  0.777004  0.040454   {'var_smoothing': 0.009540954763499934}
# 7  0.775880  0.041966  {'var_smoothing': 0.0062505519252739694}
# 8  0.775880  0.041966   {'var_smoothing': 0.004094915062380423}
# 9  0.775880  0.042166  {'var_smoothing': 0.0007543120063354615}

# %%
df_best_result_GNB = pd.DataFrame(df_GaussianNB_results.iloc[0,:]).T
df_best_result_GNB['Model'] = "GaussianNB"
df_best_result_GNB
# Out:
#      means    stds                                 params       Model
# 0  0.77963  0.0376  {'var_smoothing': 0.0517947467923121}  GaussianNB

# %%
model = GaussianNB(var_smoothing = 0.0517947467923121).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  444  105
# 1   92  250

# %%
df_best_result_GNB['Recall'] = model_result['test_recall'].mean()
df_best_result_GNB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_GNB['Iteration'] = 4
df_best_result_GNB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_GNB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.5. Perceptron

# %%
#define the model
model = Perceptron()

#define the parameters to search
eta0 = [0.0001,0.001,0.01,0.1,1.0]
max_iter = [10,100,1000,10000]
early_stopping = [True,False]
penalty = ['l2','l1',None]

#define grid search
grid = dict(eta0 = eta0,
           max_iter = max_iter,
           early_stopping = early_stopping,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 120 candidates, totalling 3600 fits
# Best: 0.727391 using {'early_stopping': False, 'eta0': 0.1, 'max_iter': 10, 'penalty': 'l1'}
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "

# %%
df_Perceptron_results = pd.DataFrame(data = results_dict)
df_Perceptron_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_Perceptron_results.reset_index(drop = True,
                               inplace = True)
df_Perceptron_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 1  0.727391  0.062105  {'early_stopping': False, 'eta0': 1.0, 'max_it...
# 2  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 3  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 4  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 5  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 6  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 7  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 8  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.001, 'max_...
# 9  0.726533  0.064768  {'early_stopping': False, 'eta0': 0.001, 'max_...

# %%
df_best_result_Per = pd.DataFrame(df_Perceptron_results.iloc[0,:]).T
df_best_result_Per['Model'] = "Perceptron"
df_best_result_Per
# Out:
#       means      stds                                             params  \
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#         Model
# 0  Perceptron

# %%
model = Perceptron(eta0 = 0.1,
           max_iter = 10,
           early_stopping = False,
           penalty = 'l1').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_stochastic_gradient.py:574: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn("Maximum number of iteration reached before "
#      0    1
# 0  358  191
# 1  125  217

# %%
df_best_result_Per['Recall'] = model_result['test_recall'].mean()
df_best_result_Per['F1_Score'] = model_result['test_f1'].mean()
df_best_result_Per['Iteration'] = 4
df_best_result_Per['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_Per],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.6. Linear SVC

# %%
#define the model
model = LinearSVC()

#define the parameters to search
c_values = [100, 10, 1.0, 0.1, 0.01]
penalty = ['l2','l1']
max_iter = [1,10,100,1000,10000]

#define grid search
grid = dict(max_iter = max_iter,
           C = c_values,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.797961 using {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
df_LinearSVC_results = pd.DataFrame(data = results_dict)
df_LinearSVC_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_LinearSVC_results.reset_index(drop = True,
                               inplace = True)
df_LinearSVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.797961  0.038658   {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 1  0.797961  0.038658   {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 2  0.797961  0.038658  {'C': 1.0, 'max_iter': 10000, 'penalty': 'l2'}
# 3  0.797591  0.038154    {'C': 0.1, 'max_iter': 100, 'penalty': 'l2'}
# 4  0.797591  0.038154   {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 5  0.797591  0.038154  {'C': 0.1, 'max_iter': 10000, 'penalty': 'l2'}
# 6  0.797591  0.038593  {'C': 100, 'max_iter': 10000, 'penalty': 'l2'}
# 7  0.796097  0.039396     {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 8  0.796092  0.039099    {'C': 1.0, 'max_iter': 100, 'penalty': 'l2'}
# 9  0.795714  0.039891    {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}

# %%
df_best_result_LSVC = pd.DataFrame(df_LinearSVC_results.iloc[0,:]).T
df_best_result_LSVC['Model'] = "LinearSVC"
df_best_result_LSVC
# Out:
#       means      stds                                         params  \
# 0  0.797961  0.038658  {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
#
#        Model
# 0  LinearSVC

# %%
model = LinearSVC(max_iter = 10000,
           C = 10,
           penalty = 'l2').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#      0    1
# 0  472   77
# 1  105  237

# %%
df_best_result_LSVC['Recall'] = model_result['test_recall'].mean()
df_best_result_LSVC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LSVC['Iteration'] = 4
df_best_result_LSVC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LSVC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.7. Stochastic Gradient Descent

# %%
#define the model
model = SGDClassifier()

#define the parameters to search
loss = ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron', 'squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
penalty = ['l2','l1']
alpha = [0.0001,0.001,0.01,0.1,1]
learning_rate = ['optimal']


#define grid search
grid = dict(loss = loss,
           alpha = alpha,
           penalty = penalty,
           learning_rate = learning_rate)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 90 candidates, totalling 2700 fits
# Best: 0.806575 using {'alpha': 0.1, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l2'}

# %%
df_SGDClassifier_results = pd.DataFrame(data = results_dict)
df_SGDClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_SGDClassifier_results.reset_index(drop = True,
                               inplace = True)
df_SGDClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 1  0.801340  0.037514  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 2  0.799080  0.042644  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 3  0.798731  0.038781  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 4  0.798714  0.042967  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 5  0.797961  0.041299  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 6  0.797586  0.042258  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 7  0.796833  0.041643  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 8  0.796471  0.040504  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 9  0.796109  0.043886  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...

# %%
df_best_result_SGDC = pd.DataFrame(df_SGDClassifier_results.iloc[0,:]).T
df_best_result_SGDC['Model'] = "SGDClassifier"
df_best_result_SGDC
# Out:
#       means      stds                                             params  \
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
#
#            Model
# 0  SGDClassifier

# %%
model = SGDClassifier(loss = 'log',
                      alpha = 0.1,
                      penalty = 'l2',
                      learning_rate = 'optimal').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  490   59
# 1  115  227

# %%
df_best_result_SGDC['Recall'] = model_result['test_recall'].mean()
df_best_result_SGDC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SGDC['Iteration'] = 4
df_best_result_SGDC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SGDC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.8. Decision Tree

# %%
#define the model
model = DecisionTreeClassifier()

#define the parameters to search
criterion = ['gini', 'entropy']
splitter = ['best','random']
#max_depth = list(range(1,100,10))
min_samples_split = list(range(2,40,2))
min_samples_leaf = list(range(1,20,2))
max_features = ['auto','sqrt','log2', None]

#define grid search
grid = dict(criterion = criterion,
           splitter = splitter,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3040 candidates, totalling 91200 fits
# Best: 0.813308 using {'criterion': 'gini', 'max_features': None, 'min_samples_leaf': 13, 'min_samples_split': 20, 'splitter': 'random'}

# %%
df_DecisionTreeClassifier_results = pd.DataFrame(data = results_dict)
df_DecisionTreeClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_DecisionTreeClassifier_results.reset_index(drop = True,
                               inplace = True)
df_DecisionTreeClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 1  0.811798  0.042728  {'criterion': 'gini', 'max_features': None, 'm...
# 2  0.810712  0.044008  {'criterion': 'gini', 'max_features': 'auto', ...
# 3  0.810699  0.044873  {'criterion': 'gini', 'max_features': None, 'm...
# 4  0.810325  0.039854  {'criterion': 'gini', 'max_features': None, 'm...
# 5  0.810325  0.045470  {'criterion': 'entropy', 'max_features': 'log2...
# 6  0.810300  0.041657  {'criterion': 'entropy', 'max_features': None,...
# 7  0.809971  0.040261  {'criterion': 'gini', 'max_features': None, 'm...
# 8  0.809971  0.040261  {'criterion': 'gini', 'max_features': None, 'm...
# 9  0.809971  0.040261  {'criterion': 'gini', 'max_features': None, 'm...

# %%
df_best_result_DTC = pd.DataFrame(df_DecisionTreeClassifier_results.iloc[0,:]).T
df_best_result_DTC['Model'] = "DecisionTreeClassifier"
df_best_result_DTC
# Out:
#       means      stds                                             params  \
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
#
#                     Model
# 0  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'gini',
                       splitter = 'random',
                       min_samples_split = 20,
                       min_samples_leaf = 13,
                       max_features = None).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  507   42
# 1  125  217

# %%
df_best_result_DTC['Recall'] = model_result['test_recall'].mean()
df_best_result_DTC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_DTC['Iteration'] = 4
df_best_result_DTC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_DTC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.9. Random Forest

# %%
#define the model
model = RandomForestClassifier()

#define the parameters to search
n_estimators = [100,1000]
criterion = ['gini','entropy']
max_depth = [10,100]
#max_depth.append(None)
min_samples_split = [4,6]
min_samples_leaf = [1,3,5]
max_features = [None]
bootstrap = [True, False]

#define grid search
grid = dict(criterion = criterion,
            n_estimators = n_estimators,
           max_depth = max_depth,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features,
           bootstrap = bootstrap)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 96 candidates, totalling 2880 fits
# Best: 0.815918 using {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 1000}

# %%
df_RandomForestClassifier_results = pd.DataFrame(data = results_dict)
df_RandomForestClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_RandomForestClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_RandomForestClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.815918  0.039451
# 1  0.815185  0.040355
# 2  0.814415  0.041458
# 3  0.814045  0.038606
# 4  0.814045  0.041445
# 5  0.814041  0.039157
# 6  0.813679  0.039337
# 7  0.813308  0.038886
# 8  0.813300  0.039547
# 9  0.813292  0.040006
#
#                                                                                                                                                      params
# 0  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 1000}
# 1  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 2  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 1000}
# 3  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 1000}
# 5  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 100}
# 6  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 1000}
# 7  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 1000}
# 8  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 100}
# 9  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 1000}

# %%
df_best_result_RF = pd.DataFrame(df_RandomForestClassifier_results.iloc[0,:]).T
df_best_result_RF['Model'] = "RandomForestClassifier"
df_best_result_RF
# Out:
#       means      stds                                             params  \
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
#
#                     Model
# 0  RandomForestClassifier

# %%
model = RandomForestClassifier(criterion = 'gini',
                               n_estimators = 1000,
                               max_depth = 10,
                               min_samples_split = 6,
                               min_samples_leaf = 5,
                               max_features = None,
                               bootstrap = True).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  498   51
# 1  114  228

# %%
df_best_result_RF['Recall'] = model_result['test_recall'].mean()
df_best_result_RF['F1_Score'] = model_result['test_f1'].mean()
df_best_result_RF['Iteration'] = 4
df_best_result_RF['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_RF],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.10. XGB Classifier

# %%
#define the model
model = XGBClassifier()

#define the parameters to search
n_estimators = [2000]
learning_rate = [0.01]
max_depth = [3]
min_child_weight = [3]
gamma = [1]
subsample = [1.0]
colsample_bytree = [1.0]

#define grid search
grid = dict(n_estimators = n_estimators,
           learning_rate = learning_rate,
           max_depth = max_depth,
           min_child_weight = min_child_weight,
           gamma = gamma,
           subsample = subsample,
           colsample_bytree = colsample_bytree,
           use_label_encoder=[False])
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3 candidates, totalling 90 fits
# [20:39:32] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best: 0.823042 using {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_XGBClassifier_results = pd.DataFrame(data = results_dict)
df_XGBClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_XGBClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_XGBClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.823042  0.034537
# 1  0.819680  0.036781
# 2  0.809567  0.036196
#
#                                                                                                                                                                     params
# 0  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 1  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 6, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 2  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 3, 'min_child_weight': 9, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_best_result_XGB = pd.DataFrame(df_XGBClassifier_results.iloc[0,:]).T
df_best_result_XGB['Model'] = "XGBClassifier"
df_best_result_XGB
# Out:
#       means      stds                                             params  \
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
#
#            Model
# 0  XGBClassifier

# %%
model = XGBClassifier(n_estimators = 2000,
                       learning_rate = 0.01,
                       max_depth = 3,
                       min_child_weight = 3,
                       gamma = 1.0,
                       subsample = 1.0,
                       colsample_bytree = 1.0,
                       use_label_encoder=[False]).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:43] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:44] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:45] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:46] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:47] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:48] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:48] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:49] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:50] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:51] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:53] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:54] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:55] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:55] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:56] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:58] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:58] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [20:51:59] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#      0    1
# 0  507   42
# 1  116  226

# %%
df_best_result_XGB['Recall'] = model_result['test_recall'].mean()
df_best_result_XGB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_XGB['Iteration'] = 4
df_best_result_XGB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_XGB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.823042  0.034537  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816667  0.040291      {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.815918  0.039451  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.813308  0.042972  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806575  0.039226  {'alpha': 0.1, 'learning_rate': 'optimal', 'lo...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.804707  0.037671  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797961  0.038658      {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0   0.77963    0.0376              {'var_smoothing': 0.0517947467923121}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.727391  0.062105  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0           XGBClassifier  0.660756  0.737308          4  0.865572
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.649076  0.725510          4  0.864343
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0  RandomForestClassifier  0.669496  0.731431          4  0.862479
# 0  DecisionTreeClassifier  0.646218  0.724837          4  0.857842
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.660756  0.718218          4  0.853991
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.643277  0.713030          4  0.853288
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0               LinearSVC  0.692857  0.721901          4  0.853469
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.731092  0.716733          4  0.819791
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.635126  0.576778          4  0.706127
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# Clearly and generally, binning Age and Fare does not give us any benefit in our model.

# %%
df_best_result.to_csv('best_result_4.csv')
