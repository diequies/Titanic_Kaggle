# %% [markdown]
# ## 1. Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve, auc
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate, cross_val_predict

# %% [markdown]
# ## 2. Load Data

# %%
df_train = pd.read_csv('train_iter_3.csv',
                      index_col = 0)
df_test = pd.read_csv('test_iter_3.csv',
                      index_col = 0)

X_train = df_train.drop('Survived',
                       axis = 1,)
Y_train = df_train.loc[:,'Survived']
X_test = df_test

df_best_result = pd.read_csv('../Iteration_2_Standardization/best_result_2.csv',
                             index_col = 0)

# %% [markdown]
# ## 3. Model

# %% [markdown]
# ### 3.1. Logistic Regression

# %%
#define the model
model = LogisticRegression()

#define the parameters to search
solvers = ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
penalty = ['l2']
c_values = [100, 10, 1.0, 0.1, 0.01]
class_weight = [None, 'balanced']

#define grid search
grid = dict(solver = solvers,
           penalty = penalty,
           C = c_values,
           class_weight = class_weight)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Best: 0.797216 using {'C': 1.0, 'class_weight': None, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
df_logistic_results = pd.DataFrame(data = results_dict)
df_logistic_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_logistic_results.reset_index(drop = True,
                               inplace = True)
df_logistic_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 1  0.795352  0.036237  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 2  0.793854  0.037244  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 3  0.793854  0.037244  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 4  0.793854  0.037244  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 5  0.793854  0.037244  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 6  0.793109  0.037031  {'C': 100, 'class_weight': None, 'penalty': 'l...
# 7  0.793104  0.037506  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 8  0.793104  0.037506  {'C': 10, 'class_weight': None, 'penalty': 'l2...
# 9  0.793104  0.037506  {'C': 10, 'class_weight': None, 'penalty': 'l2...

# %%
df_best_result_LR = pd.DataFrame(df_logistic_results.iloc[0,:]).T
df_best_result_LR['Model'] = "Logistic_Regression"
df_best_result_LR
# Out:
#       means      stds                                             params  \
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
#
#                  Model
# 0  Logistic_Regression

# %%
model = LogisticRegression(solver = 'liblinear',
                           penalty = 'l2',
                           C = 1.0,
                           class_weight = None)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  469   80
# 1  100  242

# %%
df_best_result_LR['Recall'] = model_result['test_recall'].mean()
df_best_result_LR['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LR['Iteration'] = 3
df_best_result_LR['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LR],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.2. Support Vector Machines

# %%
#define the model
model = SVC()

#define the parameters to search
kernel = ['poly','rbf']#['linear','poly','rbf','sigmoid']
c_values = [10,1.0,0.1]#[100, 10, 1.0, 0.1, 0.01]
gamma = ['scale', 1, 0.1, 0.01, 0.001]

#define grid search
grid = dict(kernel = kernel,
           C = c_values,
           gamma = gamma)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 30 candidates, totalling 900 fits
# Best: 0.816309 using {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
df_SVC_results = pd.DataFrame(data = results_dict)
df_SVC_results.sort_values(by = 'means',
                            axis = 0,
                            inplace = True,
                            ascending = False)
df_SVC_results.reset_index(drop = True,
                               inplace = True)
df_SVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.816309  0.036852    {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 1  0.815194  0.036962         {'C': 10, 'gamma': 1, 'kernel': 'poly'}
# 2  0.813691  0.038420          {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 3  0.812568  0.035894        {'C': 1.0, 'gamma': 1, 'kernel': 'poly'}
# 4  0.812193  0.036210  {'C': 1.0, 'gamma': 'scale', 'kernel': 'poly'}
# 5  0.811078  0.037340   {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}
# 6  0.811074  0.037353   {'C': 1.0, 'gamma': 'scale', 'kernel': 'rbf'}
# 7  0.809950  0.037455         {'C': 1.0, 'gamma': 1, 'kernel': 'rbf'}
# 8  0.808082  0.038496        {'C': 0.1, 'gamma': 1, 'kernel': 'poly'}
# 9  0.803958  0.041210  {'C': 0.1, 'gamma': 'scale', 'kernel': 'poly'}

# %%
df_best_result_SVM = pd.DataFrame(df_SVC_results.iloc[0,:]).T
df_best_result_SVM['Model'] = "SVC"
df_best_result_SVM
# Out:
#       means      stds                                        params Model
# 0  0.816309  0.036852  {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}   SVC

# %%
model = SVC(kernel = 'rbf',
           C = 10,
           gamma = 'scale').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  513   36
# 1  129  213

# %%
df_best_result_SVM['Recall'] = model_result['test_recall'].mean()
df_best_result_SVM['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SVM['Iteration'] = 3
df_best_result_SVM['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SVM],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.3. Naive Bayes Classifiers

# %%
#define the model
model = GaussianNB()

#define the parameters to search
var_smoothing = np.logspace(0, -9, num = 50) 

#define grid search
grid = dict(var_smoothing = var_smoothing)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.799854 using {'var_smoothing': 0.6551285568595508}

# %%
df_GaussianNB_results = pd.DataFrame(data = results_dict)
df_GaussianNB_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_GaussianNB_results.reset_index(drop = True,
                               inplace = True)
df_GaussianNB_results.head(10)
# Out:
#       means      stds                                   params
# 0  0.799854  0.030110    {'var_smoothing': 0.6551285568595508}
# 1  0.791265  0.026341                   {'var_smoothing': 1.0}
# 2  0.785243  0.037089    {'var_smoothing': 0.4291934260128778}
# 3  0.782243  0.039526     {'var_smoothing': 0.281176869797423}
# 4  0.778514  0.042478   {'var_smoothing': 0.12067926406393285}
# 5  0.778506  0.041820    {'var_smoothing': 0.1842069969326716}
# 6  0.777769  0.040266   {'var_smoothing': 0.07906043210907697}
# 7  0.777387  0.040384   {'var_smoothing': 0.03393221771895328}
# 8  0.777020  0.039886    {'var_smoothing': 0.0517947467923121}
# 9  0.776638  0.038823  {'var_smoothing': 0.022229964825261943}

# %%
df_best_result_GNB = pd.DataFrame(df_GaussianNB_results.iloc[0,:]).T
df_best_result_GNB['Model'] = "GaussianNB"
df_best_result_GNB
# Out:
#       means     stds                                 params       Model
# 0  0.799854  0.03011  {'var_smoothing': 0.6551285568595508}  GaussianNB

# %%
model = GaussianNB(var_smoothing = 0.6551285568595508).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  509   40
# 1  131  211

# %%
df_best_result_GNB['Recall'] = model_result['test_recall'].mean()
df_best_result_GNB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_GNB['Iteration'] = 3
df_best_result_GNB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_GNB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.5. Perceptron

# %%
#define the model
model = Perceptron()

#define the parameters to search
eta0 = [0.0001,0.001,0.01,0.1,1.0]
max_iter = [10,100,1000,10000]
early_stopping = [True,False]
penalty = ['l2','l1',None]

#define grid search
grid = dict(eta0 = eta0,
           max_iter = max_iter,
           early_stopping = early_stopping,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 120 candidates, totalling 3600 fits
# Best: 0.764686 using {'early_stopping': False, 'eta0': 0.1, 'max_iter': 100, 'penalty': 'l1'}

# %%
df_Perceptron_results = pd.DataFrame(data = results_dict)
df_Perceptron_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_Perceptron_results.reset_index(drop = True,
                               inplace = True)
df_Perceptron_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 1  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 2  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 3  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 4  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 5  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 6  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 7  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 8  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...
# 9  0.745298  0.073547  {'early_stopping': False, 'eta0': 0.0001, 'max...

# %%
df_best_result_Per = pd.DataFrame(df_Perceptron_results.iloc[0,:]).T
df_best_result_Per['Model'] = "Perceptron"
df_best_result_Per
# Out:
#       means      stds                                             params  \
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#         Model
# 0  Perceptron

# %%
model = Perceptron(eta0 = 0.1,
           max_iter = 100,
           early_stopping = False,
           penalty = 'l1').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  429  120
# 1  148  194

# %%
df_best_result_Per['Recall'] = model_result['test_recall'].mean()
df_best_result_Per['F1_Score'] = model_result['test_f1'].mean()
df_best_result_Per['Iteration'] = 3
df_best_result_Per['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_Per],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.6. Linear SVC

# %%
#define the model
model = LinearSVC()

#define the parameters to search
c_values = [100, 10, 1.0, 0.1, 0.01]
penalty = ['l2','l1']
max_iter = [1,10,100,1000,10000]

#define grid search
grid = dict(max_iter = max_iter,
           C = c_values,
           penalty = penalty)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 50 candidates, totalling 1500 fits
# Best: 0.799084 using {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
df_LinearSVC_results = pd.DataFrame(data = results_dict)
df_LinearSVC_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_LinearSVC_results.reset_index(drop = True,
                               inplace = True)
df_LinearSVC_results.head(10)
# Out:
#       means      stds                                          params
# 0  0.799084  0.042820     {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 1  0.799084  0.042820    {'C': 0.1, 'max_iter': 100, 'penalty': 'l2'}
# 2  0.799084  0.042820   {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 3  0.799084  0.042820  {'C': 0.1, 'max_iter': 10000, 'penalty': 'l2'}
# 4  0.795352  0.039761    {'C': 1.0, 'max_iter': 100, 'penalty': 'l2'}
# 5  0.795352  0.039761   {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 6  0.795352  0.039761  {'C': 1.0, 'max_iter': 10000, 'penalty': 'l2'}
# 7  0.794969  0.038108    {'C': 10, 'max_iter': 1000, 'penalty': 'l2'}
# 8  0.794969  0.038108   {'C': 10, 'max_iter': 10000, 'penalty': 'l2'}
# 9  0.794640  0.039682   {'C': 100, 'max_iter': 1000, 'penalty': 'l2'}

# %%
df_best_result_LSVC = pd.DataFrame(df_LinearSVC_results.iloc[0,:]).T
df_best_result_LSVC['Model'] = "LinearSVC"
df_best_result_LSVC
# Out:
#       means     stds                                       params      Model
# 0  0.799084  0.04282  {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}  LinearSVC

# %%
model = LinearSVC(max_iter = 10,
           C = 0.1,
           penalty = 'l2').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /home/diego/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
#      0    1
# 0  472   77
# 1  103  239

# %%
df_best_result_LSVC['Recall'] = model_result['test_recall'].mean()
df_best_result_LSVC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_LSVC['Iteration'] = 3
df_best_result_LSVC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_LSVC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.7. Stochastic Gradient Descent

# %%
#define the model
model = SGDClassifier()

#define the parameters to search
loss = ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron', 'squared_loss', 'huber', 'epsilon_insensitive', 'squared_epsilon_insensitive']
penalty = ['l2','l1']
alpha = [0.0001,0.001,0.01,0.1,1]
learning_rate = ['optimal']


#define grid search
grid = dict(loss = loss,
           alpha = alpha,
           penalty = penalty,
           learning_rate = learning_rate)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 90 candidates, totalling 2700 fits
# Best: 0.801694 using {'alpha': 0.001, 'learning_rate': 'optimal', 'loss': 'log', 'penalty': 'l1'}

# %%
df_SGDClassifier_results = pd.DataFrame(data = results_dict)
df_SGDClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_SGDClassifier_results.reset_index(drop = True,
                               inplace = True)
df_SGDClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 1  0.801328  0.038565  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 2  0.797948  0.043233  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 3  0.794969  0.041172  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 4  0.794969  0.046294  {'alpha': 0.0001, 'learning_rate': 'optimal', ...
# 5  0.792701  0.040958  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 6  0.792330  0.043605  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 7  0.790495  0.039710  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 8  0.789001  0.043823  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 9  0.788618  0.042366  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...

# %%
df_best_result_SGDC = pd.DataFrame(df_SGDClassifier_results.iloc[0,:]).T
df_best_result_SGDC['Model'] = "SGDClassifier"
df_best_result_SGDC
# Out:
#       means      stds                                             params  \
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
#
#            Model
# 0  SGDClassifier

# %%
model = SGDClassifier(loss = 'log',
                      alpha = 0.001,
                      penalty = 'l1',
                      learning_rate = 'optimal').fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  469   80
# 1  102  240

# %%
df_best_result_SGDC['Recall'] = model_result['test_recall'].mean()
df_best_result_SGDC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_SGDC['Iteration'] = 3
df_best_result_SGDC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_SGDC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.8. Decision Tree

# %%
#define the model
model = DecisionTreeClassifier()

#define the parameters to search
criterion = ['gini', 'entropy']
splitter = ['best','random']
#max_depth = list(range(1,100,10))
min_samples_split = list(range(2,40,2))
min_samples_leaf = list(range(1,20,2))
max_features = ['auto','sqrt','log2', None]

#define grid search
grid = dict(criterion = criterion,
           splitter = splitter,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3040 candidates, totalling 91200 fits
# Best: 0.820803 using {'criterion': 'gini', 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 2, 'splitter': 'best'}

# %%
df_DecisionTreeClassifier_results = pd.DataFrame(data = results_dict)
df_DecisionTreeClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_DecisionTreeClassifier_results.reset_index(drop = True,
                               inplace = True)
df_DecisionTreeClassifier_results.head(10)
# Out:
#       means      stds                                             params
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 1  0.819297  0.038753  {'criterion': 'gini', 'max_features': None, 'm...
# 2  0.818931  0.042285  {'criterion': 'gini', 'max_features': None, 'm...
# 3  0.818181  0.039990  {'criterion': 'gini', 'max_features': None, 'm...
# 4  0.817420  0.035116  {'criterion': 'gini', 'max_features': None, 'm...
# 5  0.817041  0.030105  {'criterion': 'entropy', 'max_features': None,...
# 6  0.816309  0.040114  {'criterion': 'gini', 'max_features': None, 'm...
# 7  0.815926  0.034893  {'criterion': 'entropy', 'max_features': None,...
# 8  0.815918  0.034114  {'criterion': 'entropy', 'max_features': None,...
# 9  0.815568  0.041247  {'criterion': 'gini', 'max_features': None, 'm...

# %%
df_best_result_DTC = pd.DataFrame(df_DecisionTreeClassifier_results.iloc[0,:]).T
df_best_result_DTC['Model'] = "DecisionTreeClassifier"
df_best_result_DTC
# Out:
#       means      stds                                             params  \
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
#
#                     Model
# 0  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(criterion = 'gini',
                       splitter = 'best',
                       min_samples_split = 2,
                       min_samples_leaf = 5,
                       max_features = None).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  481   68
# 1   98  244

# %%
df_best_result_DTC['Recall'] = model_result['test_recall'].mean()
df_best_result_DTC['F1_Score'] = model_result['test_f1'].mean()
df_best_result_DTC['Iteration'] = 3
df_best_result_DTC['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_DTC],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.9. Random Forest

# %%
#define the model
model = RandomForestClassifier()

#define the parameters to search
n_estimators = [100,1000]
criterion = ['gini','entropy']
max_depth = [10,100]
#max_depth.append(None)
min_samples_split = [4,6]
min_samples_leaf = [1,3,5]
max_features = [None]
bootstrap = [True, False]

#define grid search
grid = dict(criterion = criterion,
            n_estimators = n_estimators,
           max_depth = max_depth,
           min_samples_split = min_samples_split,
           min_samples_leaf = min_samples_leaf,
           max_features = max_features,
           bootstrap = bootstrap)
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 96 candidates, totalling 2880 fits
# Best: 0.836488 using {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}

# %%
df_RandomForestClassifier_results = pd.DataFrame(data = results_dict)
df_RandomForestClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_RandomForestClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_RandomForestClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.836488  0.033072
# 1  0.835372  0.035717
# 2  0.835368  0.033807
# 3  0.835360  0.036656
# 4  0.833121  0.034727
# 5  0.832380  0.039670
# 6  0.831993  0.033698
# 7  0.831619  0.034303
# 8  0.831253  0.036430
# 9  0.830882  0.034584
#
#                                                                                                                                                      params
# 0  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 1  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 100}
# 2  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 1000}
# 3  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 1000}
# 4  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 100}
# 5  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 100}
# 6  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 1000}
# 7  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 8  {'bootstrap': True, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 1000}
# 9  {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 1000}

# %%
df_best_result_RF = pd.DataFrame(df_RandomForestClassifier_results.iloc[0,:]).T
df_best_result_RF['Model'] = "RandomForestClassifier"
df_best_result_RF
# Out:
#       means      stds                                             params  \
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
#
#                     Model
# 0  RandomForestClassifier

# %%
model = RandomForestClassifier(criterion = 'entropy',
                               n_estimators = 100,
                               max_depth = 10,
                               min_samples_split = 4,
                               min_samples_leaf = 1,
                               max_features = None,
                               bootstrap = True).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
#      0    1
# 0  496   53
# 1   96  246

# %%
df_best_result_RF['Recall'] = model_result['test_recall'].mean()
df_best_result_RF['F1_Score'] = model_result['test_f1'].mean()
df_best_result_RF['Iteration'] = 3
df_best_result_RF['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_RF],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# ### 3.10. XGB Classifier

# %%
#define the model
model = XGBClassifier()

#define the parameters to search
n_estimators = [2000]
learning_rate = [0.01]
max_depth = [9]
min_child_weight = [3]
gamma = [1]
subsample = [1.0]
colsample_bytree = [1.0]

#define grid search
grid = dict(n_estimators = n_estimators,
           learning_rate = learning_rate,
           max_depth = max_depth,
           min_child_weight = min_child_weight,
           gamma = gamma,
           subsample = subsample,
           colsample_bytree = colsample_bytree,
           use_label_encoder=[False])
cv = RepeatedStratifiedKFold(n_splits = 10, 
                             n_repeats = 3, 
                             random_state = 1)
grid_search = GridSearchCV(estimator = model,
                          param_grid = grid,
                          n_jobs = -1,
                          cv = cv,
                          scoring = 'accuracy',
                          error_score = 0,
                          verbose = 2)
grid_result = grid_search.fit(X_train, Y_train)

#summarize results
print('Best: %f using %s' % (grid_result.best_score_,
                            grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
results_dict = dict(means = means,
                  stds = stds,
                  params = params)
# Out:
# Fitting 30 folds for each of 3 candidates, totalling 90 fits
# [15:14:01] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Best: 0.839118 using {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_XGBClassifier_results = pd.DataFrame(data = results_dict)
df_XGBClassifier_results.sort_values(by = ['means','stds'],
                            axis = 0,
                            inplace = True,
                            ascending = [False,True])
df_XGBClassifier_results.reset_index(drop = True,
                               inplace = True)
with pd.option_context('display.max_colwidth', -1):     
    display(df_XGBClassifier_results.head(10))
# Out:
#       means      stds  \
# 0  0.839118  0.035118
# 1  0.836488  0.037644
# 2  0.825273  0.035653
#
#                                                                                                                                                                     params
# 0  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.01, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 1  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 0.1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}
# 2  {'colsample_bytree': 1.0, 'gamma': 1, 'learning_rate': 1, 'max_depth': 9, 'min_child_weight': 3, 'n_estimators': 2000, 'subsample': 1.0, 'use_label_encoder': False}

# %%
df_best_result_XGB = pd.DataFrame(df_XGBClassifier_results.iloc[0,:]).T
df_best_result_XGB['Model'] = "XGBClassifier"
df_best_result_XGB
# Out:
#       means      stds                                             params  \
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
#
#            Model
# 0  XGBClassifier

# %%
model = XGBClassifier(n_estimators = 2000,
                       learning_rate = 0.01,
                       max_depth = 9,
                       min_child_weight = 3,
                       gamma = 1.0,
                       subsample = 1.0,
                       colsample_bytree = 1.0,
                       use_label_encoder=[False]).fit(X_train, Y_train)
model_result = cross_validate(model, X_train, Y_train, cv = 10,
                             scoring = ('accuracy', 'recall', 'f1','roc_auc'))
y_pred = cross_val_predict(model, X_train, Y_train, cv = 10)
pd.DataFrame(confusion_matrix(Y_train, y_pred))
# Out:
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:27:50] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:27:52] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:27:54] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:27:57] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:00] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:02] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:04] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:06] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:08] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:09] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:11] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:13] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:14] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:16] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:18] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:20] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:21] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:23] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:25] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:27] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /home/diego/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:28:29] WARNING: /tmp/build/80754af9/xgboost-split_1619724447847/work/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#      0    1
# 0  493   56
# 1   92  250

# %%
df_best_result_XGB['Recall'] = model_result['test_recall'].mean()
df_best_result_XGB['F1_Score'] = model_result['test_f1'].mean()
df_best_result_XGB['Iteration'] = 3
df_best_result_XGB['AUC'] = model_result['test_roc_auc'].mean()
df_best_result = pd.concat([df_best_result,df_best_result_XGB],
         axis = 0)

# %%
df_best_result.sort_values('means',
                          axis = 0,
                          ascending = False)
# Out:
#       means      stds                                             params  \
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839867  0.034705  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.839118  0.035118  {'colsample_bytree': 1.0, 'gamma': 1, 'learnin...
# 0  0.836488  0.033072  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.835377  0.035897  {'bootstrap': True, 'criterion': 'gini', 'max_...
# 0  0.834236  0.036355  {'bootstrap': True, 'criterion': 'entropy', 'm...
# 0  0.823774  0.040589          {'C': 1.0, 'gamma': 0.1, 'kernel': 'rbf'}
# 0  0.821556  0.040146  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820803  0.039562  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.820054  0.038923  {'criterion': 'gini', 'max_features': None, 'm...
# 0  0.816309  0.036852       {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# 0  0.807686  0.041278  {'C': 0.01, 'class_weight': None, 'penalty': '...
# 0  0.806188  0.033791  {'alpha': 1, 'learning_rate': 'optimal', 'loss...
# 0  0.805814  0.043604  {'C': 0.1, 'class_weight': None, 'penalty': 'l...
# 0  0.801694  0.043257  {'alpha': 0.001, 'learning_rate': 'optimal', '...
# 0  0.799854   0.03011              {'var_smoothing': 0.6551285568595508}
# 0  0.799084   0.04282        {'C': 0.1, 'max_iter': 10, 'penalty': 'l2'}
# 0  0.797216  0.040543  {'C': 1.0, 'class_weight': None, 'penalty': 'l...
# 0  0.796846  0.043395      {'C': 0.1, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.796088  0.038906      {'C': 1.0, 'max_iter': 1000, 'penalty': 'l2'}
# 0  0.783379  0.049593  {'alpha': 0.01, 'learning_rate': 'optimal', 'l...
# 0  0.778136   0.03604             {'var_smoothing': 0.12067926406393285}
# 0  0.778136  0.033252            {'var_smoothing': 4.71486636345739e-06}
# 0  0.764686  0.080498  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.749351  0.034313       {'leaf_size': 26, 'n_neighbors': 11, 'p': 1}
# 0  0.738077  0.084509  {'early_stopping': False, 'eta0': 0.1, 'max_it...
# 0  0.670121   0.10997  {'early_stopping': False, 'eta0': 0.1, 'max_it...
#
#                     Model    Recall  F1_Score  Iteration       AUC
# 0           XGBClassifier  0.731176  0.767082          2  0.872206
# 0           XGBClassifier  0.728151  0.773902          1  0.874456
# 0           XGBClassifier  0.731176  0.767082          3  0.872100
# 0  RandomForestClassifier  0.733782  0.774810          3  0.864874
# 0  RandomForestClassifier  0.728151  0.770911          2  0.870139
# 0  RandomForestClassifier  0.739748  0.774462          1  0.870070
# 0                     SVC  0.689832  0.743660          2  0.863829
# 0  DecisionTreeClassifier  0.716639  0.743771          2  0.831876
# 0  DecisionTreeClassifier  0.716639  0.742604          3  0.832576
# 0  DecisionTreeClassifier  0.713697  0.744158          1  0.832947
# 0                     SVC  0.623025  0.718089          3  0.856714
# 0     Logistic_Regression  0.666723  0.722555          2  0.854166
# 0           SGDClassifier  0.596471  0.700332          2  0.850851
# 0     Logistic_Regression  0.675462  0.720547          1  0.851122
# 0           SGDClassifier  0.684706  0.705259          3  0.855592
# 0              GaussianNB  0.617143  0.710119          3  0.845042
# 0               LinearSVC  0.698739  0.724848          3  0.854022
# 0     Logistic_Regression  0.707563  0.727479          3  0.854349
# 0               LinearSVC  0.687059  0.716760          1  0.852308
# 0               LinearSVC  0.695798  0.714681          2  0.854989
# 0           SGDClassifier  0.692605  0.688880          1  0.795769
# 0              GaussianNB  0.684286  0.709341          2  0.817319
# 0              GaussianNB  0.684286  0.704172          1  0.815629
# 0              Perceptron  0.567983  0.553907          3  0.818814
# 0              KNeighbors  0.576050  0.616377          1  0.784931
# 0              Perceptron  0.707899  0.665674          2  0.736096
# 0              Perceptron  0.601513  0.552488          1  0.769971

# %% [markdown]
# It seems that the performance of standardization is better than the one of normalization, therefore for next iterations I will keep the standardization.

# %%
df_best_result.to_csv('best_result_3.csv')
